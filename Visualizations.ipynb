# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
# %run -m simplepytorch.plot_perf "waveletmlp" -c "BAcc AVG" --mode 3
clear_output(wait=True)
plt.figure(1)   
plt.legend(loc="lower right")
