# %%
# !python deepfix/train.py -h
# Out:
# python: can't open file '/ocean/projects/cie160013p/elvinj/DeepFix/deepfix/deepfix/train.py': [Errno 2] No such file or directory

# %%
# pwd
# Out:
# '/ocean/projects/cie160013p/elvinj/DeepFix/deepfix'

# %%
# cd ..
# Out:
# /ocean/projects/cie160013p/elvinj/DeepFix

# %%
# !ls results/debugging
# Out:
# checkpoints

# %%
# cd deepfix
# Out:
# /ocean/projects/cie160013p/elvinj/DeepFix/deepfix

# %%
# !./results/debugging/plot.perf
# !results/debugging/perf.csv
# !simplepytorch_plot debugging -c "Loss AVG"
# plt

# %%
ls
# Out:
#  CNN+SVM.ipynb           Code-Copy7.ipynb        init_from_distribution.py
# 'Code-Copy-(-1).ipynb'   Code-Copy8.ipynb        models/
#  Code-Copy0.ipynb        Code-Copy9.ipynb        plotting.py
#  Code-Copy1.ipynb        Code.ipynb              pruning.py
#  Code-Copy2.ipynb        Untitled.ipynb          requirements.txt
#  Code-Copy3.ipynb        __pycache__/            results/
#  Code-Copy4.ipynb        analyze_layer.py        train.py
#  Code-Copy5.ipynb        deepfix_strategies.py   weight_saliency.py
#  Code-Copy6.ipynb        feature_csv/

# %%
import os
l = os.listdir('results')
l.sort()
l
# Out:
# ['.ipynb_checkpoints',
#  'debugging',
#  'model_efficientnet-b0:imagenet:1:14_in_ch_1out_ch_14',
#  'model_efficientnet-b1:imagenet:1:14_in_ch_1out_ch_14',
#  'model_effnetv2:untrained:1:14_in_ch_1out_ch_14',
#  'model_resnet18:imagenet:1:14_in_ch_1_out_ch_14',
#  'model_resnet18:imagenet:3:3_in_ch_3out_ch_3',
#  'model_resnet50:imagenet:1:14_in_ch_1out_ch_14',
#  'model_resnet50:imagenet:3:3_in_ch_3out_ch_3',
#  'model_waveletmlp:300:1:14:1:128:1:2_level_1_patch_size_128',
#  'model_waveletmlp:300:1:14:1:1:1:2_level_1_patch_size_1',
#  'model_waveletmlp:300:1:14:1:1:1:2_patch_size_1_level_1',
#  'model_waveletmlp:300:1:14:1:256:1:2_level_1_patch_size_256',
#  'model_waveletmlp:300:1:14:1:2:1:2_patch_size_1_level_2',
#  'model_waveletmlp:300:1:14:1:32:1:2_level_1_patch_size_32',
#  'model_waveletmlp:300:1:14:1:3:1:2_patch_size_1_level_3',
#  'model_waveletmlp:300:1:14:1:4:1:2_patch_size_1_level_4',
#  'model_waveletmlp:300:1:14:1:5:1:2_patch_size_1_level_5',
# ...

# %%
# %run -m simplepytorch.plot_perf model_resnet18:imagenet:1:14_in_ch_1_out_ch_14 -c "Loss" --no-shell --mode 4
# Out:
# Namespace(runid_regex='model_resnet18:imagenet:1:14_in_ch_1_out_ch_14', data_dir='./results', data_fp_regex='perf.*\\.csv$', rolling_mean=None, hdf_table_name=None, col_regex='Loss', index_col='epoch', mode=4, mode1_savefig_dir='./results/plots/mode1', mode2_savefig_dir='./results/plots/mode2', mode3_savefig_dir='./results/plots/mode3', mode3_ci=None, mode4_groupby='(Train|Val|Test) (.*):2', mode4_allruns=-1, best_effort=False, savefig=False, no_plot=False, shell=False, legend=True, avg_cols=False)
# -1
# found data ./results/model_resnet18:imagenet:1:14_in_ch_1_out_ch_14/perf.csv
# ...

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:6:1:1:2_level_6_patch_size_1 -c "Loss" --no-shell --mode 4
# Out:
# Namespace(runid_regex='model_waveletmlp:300:1:14:6:1:1:2_level_6_patch_size_1', data_dir='./results', data_fp_regex='perf.*\\.csv$', rolling_mean=None, hdf_table_name=None, col_regex='Loss', index_col='epoch', mode=4, mode1_savefig_dir='./results/plots/mode1', mode2_savefig_dir='./results/plots/mode2', mode3_savefig_dir='./results/plots/mode3', mode3_ci=None, mode4_groupby='(Train|Val|Test) (.*):2', mode4_allruns=-1, best_effort=False, savefig=False, no_plot=False, shell=False, legend=True, avg_cols=False)
# -1
# found data ./results/model_waveletmlp:300:1:14:6:1:1:2_level_6_patch_size_1/perf.csv
# ...

# %%
# %run -m simplepytorch.plot_perf model_resnet18:imagenet:3:3_in_ch_3out_ch_3 -c "Loss" --no-shell --mode 4
# Out:
# Namespace(runid_regex='model_resnet18:imagenet:3:3_in_ch_3out_ch_3', data_dir='./results', data_fp_regex='perf.*\\.csv$', rolling_mean=None, hdf_table_name=None, col_regex='Loss', index_col='epoch', mode=4, mode1_savefig_dir='./results/plots/mode1', mode2_savefig_dir='./results/plots/mode2', mode3_savefig_dir='./results/plots/mode3', mode3_ci=None, mode4_groupby='(Train|Val|Test) (.*):2', mode4_allruns=-1, best_effort=False, savefig=False, no_plot=False, shell=False, legend=True, avg_cols=False)
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/deepfix/lib/python3.9/runpy.py in run_module(mod_name, init_globals, run_name, alter_sys)
#     208         run_name = mod_name
#     209     if alter_sys:
# --> 210         return _run_module_code(code, init_globals, run_name, mod_spec)
#     211     else:
#     212         # Leave the sys module alone
#
# ...

# %%
for folder in l:
    # %run -m simplepytorch.plot_perf folder -c "Loss" --no-shell --mode 4
#     plt.show()
# Out:
# Namespace(runid_regex='folder', data_dir='./results', data_fp_regex='perf.*\\.csv$', rolling_mean=None, hdf_table_name=None, col_regex='Loss', index_col='epoch', mode=4, mode1_savefig_dir='./results/plots/mode1', mode2_savefig_dir='./results/plots/mode2', mode3_savefig_dir='./results/plots/mode3', mode3_ci=None, mode4_groupby='(Train|Val|Test) (.*):2', mode4_allruns=-1, best_effort=False, savefig=False, no_plot=False, shell=False, legend=True, avg_cols=False)
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/deepfix/lib/python3.9/runpy.py in run_module(mod_name, init_globals, run_name, alter_sys)
#     208         run_name = mod_name
#     209     if alter_sys:
# --> 210         return _run_module_code(code, init_globals, run_name, mod_spec)
#     211     else:
#     212         # Leave the sys module alone
#
# ...

# %%
# %run -m simplepytorch.plot_perf model_efficientnet-b0:imagenet:1:14_in_ch_1out_ch_14 -c "Loss" --no-shell --mode 4
# Out:
# Namespace(runid_regex='model_efficientnet-b0:imagenet:1:14_in_ch_1out_ch_14', data_dir='./results', data_fp_regex='perf.*\\.csv$', rolling_mean=None, hdf_table_name=None, col_regex='Loss', index_col='epoch', mode=4, mode1_savefig_dir='./results/plots/mode1', mode2_savefig_dir='./results/plots/mode2', mode3_savefig_dir='./results/plots/mode3', mode3_ci=None, mode4_groupby='(Train|Val|Test) (.*):2', mode4_allruns=-1, best_effort=False, savefig=False, no_plot=False, shell=False, legend=True, avg_cols=False)
# -1
# found data ./results/model_efficientnet-b0:imagenet:1:14_in_ch_1out_ch_14/perf.csv
# ...

# %%
# !python deepfix/train.py -h
# Out:
# WARNING:root:QualDR dataset labels unavailable because pyjq not installed
# usage: train.py [-h] [--epochs int] [--start_epoch int] [--device str] --dset
#                 str [--opt str] --lossfn str [--loss_reg str] [--model str]
#                 [--deepfix str] [--experiment_id str] [--prune str]
#
# optional arguments:
#   -h, --help           show this help message and exit
#
# TrainOptions ['TrainOptions']:
#   High-level configuration for training PyTorch models
#       on the CheXpert or IntelMobileODTCervical datasets.
#
#
#   --epochs int         (default: 50)
#   --start_epoch int    if "--start_epoch 1", then don't evaluate perf before
#                        training. (default: 0)
#   --device str         (default: cuda)
#   --dset str           Choose the dataset. Some options: --dset
#                        intel_mobileodt:train:val:test:v1 --dset
#                        intel_mobileodt:train+additional:val:test:v1 --dset
# ...

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	CheXpert-v1.0-small
# 	Nvidia-smi.ipynb
# 	deepfix/Code.ipynb
# 	deepfix/Untitled.ipynb
# 	third_party/pytorch_wavelets/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git fetch; git rebase origin/main
# Out:
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 25 (delta 19), reused 22 (delta 16), pack-reused 0
# Unpacking objects: 100% (25/25), done.
# From github.com:adgaudio/DeepFix
#    c721476..649baec  main       -> origin/main
#  * [new branch]      alex       -> origin/alex
# First, rewinding head to replay your work on top of it...
# Fast-forwarded main to origin/main.
