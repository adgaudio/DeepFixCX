# %%
"""
Boilerplate to implement training different networks on different datasets
with varying config.

I wish a machine could automate setting up decent baseline models and datasets
"""
#  import json
import os
from os.path import exists
import pampy
from simple_parsing import ArgumentParser, choice
from simplepytorch import datasets as D
from simplepytorch import trainlib as TL
from simplepytorch import metrics
from sklearn.model_selection import StratifiedShuffleSplit
from torch.utils.data import Dataset, DataLoader
from typing import Union, Optional
import dataclasses as dc
import numpy as np
import torch as T
import torchvision.transforms as tvt

from deepfix.models import get_effnetv2, get_resnet, get_efficientnetv1, get_DeepFixEnd2End, DeepFixMLP
from deepfix.models.ghaarconv import convert_conv2d_to_gHaarConv2d
from deepfix.init_from_distribution import init_from_beta, reset_optimizer
from deepfix import deepfix_strategies as dfs
import pytorch_wavelets as pyw
# Out:
# WARNING:root:QualDR dataset labels unavailable because pyjq not installed

# %%
MODELS = {
    ('effnetv2', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_effnetv2(pretrain, int(in_ch), int(out_ch))),
    ('resnet50', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_resnet('resnet50', pretrain, int(in_ch), int(out_ch))),
    ('resnet18', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_resnet('resnet18', pretrain, int(in_ch), int(out_ch))),
    ('efficientnet-b0', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_efficientnetv1('efficientnet-b0', pretrain, int(in_ch), int(out_ch))),
    ('efficientnet-b1', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_efficientnetv1('efficientnet-b1', pretrain, int(in_ch), int(out_ch))),
    ('waveletres18', str, str, str): lambda pretrain, in_ch, out_ch: R(
        pretrain, int(in_ch), int(out_ch)),
    ('waveletmlp', str, str, str, str, str, str, str): (
        lambda mlp_channels, in_ch, out_ch, wavelet_levels, patch_size, in_ch_mul, mlp_depth: get_DeepFixEnd2End(
            int(in_ch), int(out_ch),
            in_ch_multiplier=int(in_ch_mul), wavelet='db1',
            wavelet_levels=int(wavelet_levels), wavelet_patch_size=int(patch_size),
            mlp_depth=int(mlp_depth), mlp_channels=int(mlp_channels),
            mlp_fix_weights='none', mlp_activation=None)
        ),

    #  ('waveletres18v2', str, str, str): lambda pretrain, in_ch, out_ch: (
        #  DeepFixCompression(levels=8, wavelet='coif1', patch_size=1),
        #  R2(pretrain, int(in_ch), int(out_ch))),
}


class R(T.nn.Module):
    def __init__(self, pretrain, in_ch, out_ch):
        super().__init__()
        self.r = get_resnet('resnet18', pretrain, in_ch, out_ch,)
        self.dwt = pyw.DWT(J=8, wave='coif1', mode='zero')

    @staticmethod
    def wavelet_coefficients_as_tensorimage(approx, detail, normalize=False):
        B,C = approx.shape[:2]
        fixed_dims = approx.shape[:-2] # num images in minibatch, num channels, etc
        output_shape = fixed_dims + (
            detail[0].shape[-2]*2,  # input img height
            detail[0].shape[-1]*2)  # input img width
        im = T.zeros(output_shape, device=approx.device, dtype=approx.dtype)
        if normalize:
            norm11 = lambda x: (x / max(x.min()*-1, x.max()))  # into [-1,+1] preserving sign
            #  approx = norm11(approx)
        im[..., :approx.shape[-2], :approx.shape[-1]] = approx if approx is not None else 0
        for level in detail:
            lh, hl, hh = level.unbind(-3)
            h,w = lh.shape[-2:]
            if normalize:
                lh, hl, hh = [norm11(x) for x in [lh, hl, hh]]
            #  im[:h, :w] = approx
            im[..., 0:h, w:w+w] = lh  # horizontal
            im[..., h:h+h, :w] = hl  # vertical
            im[..., h:h+h, w:w+w] = hh  # diagonal
        return im

    def forward(self, x):
        x = self.wavelet_coefficients_as_tensorimage(*self.dwt(x))
        return self.r(x)


class R2(T.nn.Module):
    def __init__(self, pretrain, in_ch, out_ch):
        super().__init__()
        self.r = get_resnet('resnet18', pretrain, in_ch, out_ch,)

    def forward(self, x):
        B,C,H = x.shape
        x = x.unsqueeze(-1).repeat(1,1,1,H)
        return self.r(x)


class LossCheXpertIdentity(T.nn.Module):
    def __init__(self, N):
        super().__init__()
        self.bce = T.nn.BCEWithLogitsLoss()
        self.N = N

    def forward(self, yhat, y):
        # absolute max possible num patients in chexpert is 223414
        # but let's just hash them into a smaller number of bins via modulo N
        assert self.N == yhat.shape[1], \
                f'note: model must have {self.N} binary predictions per sample'
        y_onehot = y.new_zeros(y.shape[0], self.N, dtype=T.float
                               ).scatter_(1, y.long()%self.N, 1)
        return self.bce(yhat[:, -1], y_onehot[:, -1])


class LossCheXpertUignore(T.nn.Module):
    def __init__(self):
        super().__init__()
        self.bce = T.nn.BCEWithLogitsLoss()

    def forward(self, yhat, y):
        ignore = (y != 2)  # ignore uncertainty labels
        return self.bce(yhat[ignore], y[ignore])


def loss_intelmobileodt(yhat, y):
    """BCE Loss with class balancing weights.

    Not sure this actually helps

    because Type 2 is the hardest class, it
    has the most samples, and it separates Type 1 from Type 3.  Arguably, Type 2
    samples are on the decision boundary between Type 1 and 3.
    Class balancing weights make it harder to focus on class 2.
    """
    #  assert y.shape == yhat.shape, 'sanity check'
    #  assert y.dtype == yhat.dtype, 'sanity check'

    # class distribution of stage='train'
    w = T.tensor([249, 781, 450], dtype=y.dtype, device=y.device)
    w = (w.max() / w).reshape(1, 3)
    # w can have any of the shapes:  (B,1) or (1,C) or (B,C)
    #  return T.nn.functional.binary_cross_entropy_with_logits(yhat, y, weight=w)
    return T.nn.functional.cross_entropy(yhat, y, weight=w)
    # can't apply focal loss unless do it manually.


def onehot(y, nclasses):
    return T.zeros((y.numel(), nclasses), dtype=y.dtype, device=y.device)\
            .scatter_(1, y.unsqueeze(1), 1)


def _upsample_pad_minibatch_imgs_to_same_size(batch, target_is_segmentation_mask=False):
    """a collate function for a dataloader of (x,y) samples.  """
    shapes = [item[0].shape for item in batch]
    H = max(h for c,h,w in shapes)
    W = max(w for c,h,w in shapes)
    X, Y = [], []
    for item in batch:
        h,w = item[0].shape[1:]
        dh, dw = (H-h), (W-w)
        padding = (dw//2, dw-dw//2, dh//2, dh-dh//2, )
        X.append(T.nn.functional.pad(item[0], padding))
        if target_is_segmentation_mask:
            Y.append(T.nn.functional.pad(item[1], padding))
        else:
            Y.append(item[1])
    return T.stack(X), T.stack(Y)


def get_dset_chexpert(train_frac=.8, val_frac=.2, small=False,
                      labels:str='diagnostic', num_identities=None):
    """
    Args:
        labels:  either "diagnostic" (the 14 classes defined as
            D.CheXpert.LABELS_DIAGNOSTIC) or "identity" ("patient", "study",
            "view", "index")
        small:  whether to use CheXpert_Small dataset (previously downsampled
            images) or the fully size dataset.
        num_identities:  used only if labels='identity'.  If
            num_identities=1000, then all patients get identified as coming
            from precisely 1 of 1000 bins.

    Returns:
        (
        {'train_dset': ..., 'val_dset': ..., 'test_dset': ...,
         'train_loader': ..., 'val_loader': ..., 'test_loader': ...
         },

        ('Pneumonia', 'Cardiomegaly', ...)  # class names defined by `labels`
        )
    """
    _label_cleanup_dct = dict(D.CheXpert.LABEL_CLEANUP_DICT)
    if labels == 'diagnostic':
        class_names = D.CheXpert.LABELS_DIAGNOSTIC
        for k in class_names:
            _label_cleanup_dct[k][np.nan] = 0  # remap missing value to negative
        get_ylabels = lambda dct: \
                D.CheXpert.format_labels(dct, labels=class_names).float()
    elif labels == 'identity':
        class_names = list(range(num_identities))
        get_ylabels = lambda dct: \
                (D.CheXpert.format_labels(dct, labels=['index']) % num_identities).long()
    else:
        raise NotImplementedError(f"unrecognized labels: {labels}")
    kws = dict(
        img_transform=tvt.Compose([
#              tvt.RandomCrop((512, 512)),
            tvt.ToTensor(),  # full res 1024x1024 imgs
        ]),
        getitem_transform=lambda dct: (dct['image'], get_ylabels(dct)),
        label_cleanup_dct=_label_cleanup_dct,
    )
    if small:
        kls = D.CheXpert_Small
    else:
        kls = D.CheXpert

    train_dset = kls(dataset_dir="../data/CheXpert-v1.0-small/",use_train_set=True, **kws)  #Edited Elvin

    N = len(train_dset)
    if train_frac + val_frac == 1:
        nsplits = [N - int(N*val_frac), int(N*val_frac), 0]
    else:
        a,b = int(N*train_frac), int(N*val_frac)
        nsplits = [a,b, N-a-b]
    train_dset, val_dset, _ = T.utils.data.random_split(train_dset, nsplits)
    test_dset = kls(dataset_dir="../data/CheXpert-v1.0-small/",use_train_set=False, **kws) #Edited Elvin
    batch_dct = dict(
        batch_size=15, collate_fn=_upsample_pad_minibatch_imgs_to_same_size,
        num_workers=int(os.environ.get("num_workers", 4)))  # upsample pad must take time
    train_loader=DataLoader(train_dset, shuffle=True, **batch_dct)
    val_loader=DataLoader(val_dset, **batch_dct)
    test_loader=DataLoader(test_dset, **batch_dct)
    return (dict(
        train_dset=train_dset, val_dset=val_dset, test_dset=test_dset,
        train_loader=train_loader, val_loader=val_loader, test_loader=test_loader,
    ), class_names)


def get_dset_intel_mobileodt(stage_trainval:str, use_val:str, stage_test:str, augment:str
                             ) -> (dict[str,Optional[Union[Dataset,DataLoader]]], tuple[str]):
    """Obtain train/val/test splits for the IntelMobileODT Cervical Cancer
    Colposcopy dataset, and the data loaders.

    Args:
        stage_trainval: the `stage` for training and validation.
            i.e. Possible choices:  {'train', 'train+additional'}
            Train / val split is 70/30 random stratified split.
        use_val: Whether to create a validation set
            Choices:  {"val", "noval"}
        stage_test: the `stage` for test set.  Should be "test".
        augment: Type of augmentations to apply.  One of {'v1', }.
            "v1" - make the aspect ratio .75, resize images to (200,150), and convert in range [0,1]
    Returns:
        (
        {'train_dset': ..., 'val_dset': ..., 'test_dset': ...,
         'train_loader': ..., 'val_loader': ..., 'test_loader': ...
         },

        ('Type 1', 'Type 2', 'Type 3')
        )
    """
    assert augment == 'v1', 'code bug: other augmentations not implemented'
    base_dir = './data/intel_mobileodt_cervical_resized'
    dset_trainval = D.IntelMobileODTCervical(stage_trainval, base_dir)
    _y = [dset_trainval.getitem(i, load_img=False)
          for i in range(len(dset_trainval))]
    dct = {'test_dset': D.IntelMobileODTCervical(stage_test, base_dir)}
    if use_val == 'noval':
        dct['train_dset'] = dset_trainval
        dct['val_dset'] = None
    else:
        assert use_val == 'val', f'unrecognized option: {use_val}'
        idxs_train, idxs_val = list(
            StratifiedShuffleSplit(1, test_size=.3).split(
                np.arange(len(dset_trainval)), _y))[0]
        dct['train_dset'] = T.utils.data.Subset(dset_trainval, idxs_train)
        dct['val_dset'] = T.utils.data.Subset(dset_trainval, idxs_val)

    # preprocess train/val/test images all the same way
    preprocess_v1 = tvt.Compose([
        #
        ### previously done (to save computation time) ###
        #  D.IntelMobileODTCervical.fix_aspect_ratio,
        #  tvt.Resize((200, 150)),  # interpolation=tvt.InterpolationMode.NEAREST),
        #
        lambda x: x.float()/255.
    ])
    dct = {k: D.PreProcess(v, lambda xy: (
        preprocess_v1(xy[0]),
        #  onehot(xy[1].unsqueeze(0).long()-1, 3).squeeze_().float()))
        xy[1].long()-1))
        for k,v in dct.items()}
    dct.update(dict(
        train_loader=DataLoader(dct['train_dset'], batch_size=20, shuffle=True),
        test_loader=DataLoader(dct['test_dset'], batch_size=20),))
    if dct['val_dset'] is None:
        dct['val_loader'] = None
    else:
        dct['val_loader'] = DataLoader(dct['val_dset'], batch_size=20)
    class_names = [x.replace('_', ' ') for x in D.IntelMobileODTCervical.LABEL_NAMES]
    return dct, class_names


LOSS_FNS = {
    ('BCEWithLogitsLoss', ): lambda _: T.nn.BCEWithLogitsLoss(),
    ('CrossEntropyLoss', ): lambda _: T.nn.CrossEntropyLoss(),
    ('CE_intelmobileodt', ): lambda _: loss_intelmobileodt,
    ('chexpert_uignore', ): lambda _: LossCheXpertUignore(),
    ('chexpert_identity', str): lambda out_ch: LossCheXpertIdentity(N=int(out_ch)),
}

DSETS = {
    ('intel_mobileodt', str, str, str, str): (
        lambda train, val, test, aug: get_dset_intel_mobileodt(train, val, test, aug)),
    #  ('origa', ... todo): ( lambda ...: get_dset_origa(...)
    #  ('riga', ... todo): ( lambda ...: get_dset_riga(...)
    ('chexpert', str, str): (
        lambda train_frac, val_frac: get_dset_chexpert(
            float(train_frac), float(val_frac), small=False, labels='diagnostic')),
    ('chexpert_small', str, str): (
        lambda train_frac, val_frac: get_dset_chexpert(
            float(train_frac), float(val_frac), small=True, labels='diagnostic')),
    ('chexpert_small_ID', str, str, str): (
        lambda num_identities, train_frac, val_frac: get_dset_chexpert(
            float(train_frac), float(val_frac), small=True,
            labels='identity', num_identities=int(num_identities))),
}


def match(spec:str, dct:dict):
    return pampy.match(spec.split(':'), *(x for y in dct.items() for x in y))


def get_model_opt_loss(
        model_spec:str, opt_spec:str, loss_spec:str, regularizer_spec:str,
        device:str) -> dict[str, Union[T.nn.Module, T.optim.Optimizer]]:
    """
    Args:
        model_spec: a string of form,
            "model_name:pretraining:in_channels:out_classes".  For example:
            "effnetv2:untrained:1:5"
        opt_spec: Specifies how to create optimizer.
            First value is a pytorch Optimizer in T.optim.*.
            Other values are numerical parameters.
            Example: "SGD:lr=.003:momentum=.9"
        device: e.g. 'cpu' or 'gpu'
    Returns:
        a pytorch model and optimizer
    """
    mdl = match(model_spec, MODELS)
    mdl = mdl.to(device, non_blocking=True)
    optimizer = reset_optimizer(opt_spec, mdl)
    loss_fn = match(loss_spec, LOSS_FNS)
    if regularizer_spec != 'none':
        loss_fn = RegularizedLoss(mdl, loss_fn, regularizer_spec)
    return dict(model=mdl, optimizer=optimizer, loss_fn=loss_fn)


class RegularizedLoss(T.nn.Module):
    def __init__(self, model, lossfn, regularizer_spec:str):
        super().__init__()
        self.lossfn = lossfn
        self.regularizer_spec = regularizer_spec
        if regularizer_spec == 'none':
            self.regularizer = lambda *y: 0
        elif regularizer_spec.startswith('deepfixmlp:'):
            lbda = float(regularizer_spec.split(':')[1])
            self.regularizer = lambda *y: (
                float(lbda) * DeepFixMLP.get_VecAttn_regularizer(model))
        else:
            raise NotImplementedError(regularizer_spec)

    def forward(self, yhat, y):
        return self.lossfn(yhat, y) + self.regularizer(yhat, y)

    def __repr__(self):
        return f'RegularizedLoss<{repr(self.lossfn)},{self.regularizer_spec}>'


def get_dset_loaders_resultfactory(dset_spec:str) -> dict:
    dct, class_names = match(dset_spec, DSETS)
    if any(dset_spec.startswith(x) for x in {'intel_mobileodt:',
                                             'chexpert_small_ID:'}):
        #  dct['result_factory'] = lambda: TL.MultiLabelBinaryClassification(
                #  class_names, binarize_fn=lambda yh: (T.sigmoid(yh)>.5).long())
        dct['result_factory'] = lambda: TL.MultiClassClassification(
                len(class_names), binarize_fn=lambda yh: yh.softmax(1).argmax(1))
    elif any(dset_spec.startswith(x) for x in {'chexpert:', 'chexpert_small:'}):
        dct['result_factory'] = lambda: CheXpertMultiLabelBinaryClassification(
            class_names, binarize_fn=lambda yh: (yh.sigmoid()>.5).long(), report_avg=True)
    else:
        raise NotImplementedError(f"I don't know how to create the result factory for {dset_spec}")
    return dct

class CheXpertMultiLabelBinaryClassification(TL.MultiLabelBinaryClassification):
    def update(self, yhat, y, loss) -> None:
        self.num_samples += yhat.shape[0]
        self.loss += loss.item()
        assert yhat.shape == y.shape
        assert yhat.ndim == 2 and yhat.shape[1] == len(self._cms), "sanity check: model outputs expected prediction shape"
        binarized = self._binarize_fn(yhat)
        assert binarized.dtype == T.long, 'sanity check binarize fn'
        assert binarized.shape == y.shape, 'sanity check binarize fn'
        ignore = (y != 2)  # ignore uncertainty labels
        for i, (kls, cm) in enumerate(self._cms.items()):
            rows = ignore[:, i]
            if rows.sum() == 0:
                continue  # don't update a confusion matrix if all data for this class is ignored
            cm += metrics.confusion_matrix(y[rows, i], binarized[rows, i], num_classes=2).cpu()


def get_deepfix_train_strategy(args:'TrainOptions'):
    deepfix_spec = args.deepfix
    if deepfix_spec == 'off':
        return TL.train_one_epoch
    elif deepfix_spec.startswith('reinit:'):
        _, N, P, R = deepfix_spec.split(':')
        return dfs.DeepFix_TrainOneEpoch(int(N), float(P), int(R), TL.train_one_epoch)
    elif deepfix_spec.startswith('dhist:'):
        fp = deepfix_spec.split(':', 1)[1]
        assert exists(fp), f'histogram file not found: {fp}'
        return dfs.DeepFix_DHist(fp)
    elif deepfix_spec.startswith('dfhist:'):
        fp = deepfix_spec.split(':', 1)[1]
        assert exists(fp), f'histogram file not found: {fp}'
        return dfs.DeepFix_DHist(fp, fixed=True)
    elif deepfix_spec == 'fixed':
        return dfs.DeepFix_DHist('', fixed=True, init_with_hist=False)
    elif deepfix_spec.startswith('beta:'):
        alpha, beta = deepfix_spec.split(':')[1:]
        return dfs.DeepFix_LambdaInit(
            lambda cfg: init_from_beta(cfg.model, float(alpha), float(beta)))
    elif deepfix_spec.startswith('ghaarconv2d:'):
        ignore_layers = deepfix_spec.split(':')[1].split(',')
        return dfs.DeepFix_LambdaInit(
            lambda cfg: (
                print(f'initialize {deepfix_spec}'),
                convert_conv2d_to_gHaarConv2d(cfg.model, ignore_layers=ignore_layers),
                reset_optimizer(args.opt, cfg.model),
                print(cfg.model)
            ))
    else:
        raise NotImplementedError(deepfix_spec)


def train_config(args:'TrainOptions') -> TL.TrainConfig:
    return TL.TrainConfig(
        **get_model_opt_loss(
            args.model, args.opt, args.lossfn, args.loss_reg, args.device),
        **get_dset_loaders_resultfactory(args.dset),
        device=args.device,
        epochs=args.epochs,
        start_epoch=args.start_epoch,
        train_one_epoch=get_deepfix_train_strategy(args),
        experiment_id=args.experiment_id,
    )


@dc.dataclass
class TrainOptions:
    """High-level configuration for training PyTorch models
    on the IntelMobileODTCervical dataset.
    """
    epochs:int = 50
    start_epoch:int = 0  # if "--start_epoch 1", then don't evaluate perf before training.
    device:str = 'cuda' if T.cuda.is_available() else 'cpu'
    dset:str = None #choice(
        #  'intel_mobileodt:train:val:test:v1',
        #  'intel_mobileodt:train+additional:val:test:v1',
        #  'intel_mobileodt:train+additional:noval:test:v1',
        #  'chexpert:.8:.2', 'chexpert:.01:.01', 'chexpert:.001:.001',
        #  'chexpert_small:.8:.2', 'chexpert_small:.01:.01',
        #   'chexpert_small:.001:.001',
        #  default='intel_mobileodt:train:val:test:v1')
    opt:str = 'SGD:lr=.001:momentum=.9:nesterov=1'
    lossfn:str = None  # choices:
        #  'BCEWithLogitsLoss',
        #  'CrossEntropyLoss', 
        #  'CE_intelmobileodt',
        #  'chexpert_uignore', 
        #  'chexpert_identity:N' for some N=num_identities predicted by model (compared to identities y%N)
    loss_reg:str = 'none'  # Optionally add a regularizer to the loss.  loss + reg.  Accepted values:  'none', 'deepfixmlp:X' where X is a positive float denoting the lambda in l1 regularizer
    model:str = 'resnet18:imagenet:3:3'  # Model specification adheres to the template "model_name:pretraining:in_ch:out_ch"
    deepfix:str = 'off'  # DeepFix Re-initialization Method.
                         #  "off" or "reinit:N:P:R" or "d[f]hist:path_to_histogram.pth"
                         #  or "beta:A:B" for A,B as (float) parameters of the beta distribution
                         # 'ghaarconv2d:layer1,layer2' Replaces all spatial convolutions with GHaarConv2d layer except the specified layers
    experiment_id:str = os.environ.get('run_id', 'debugging')
    prune:str = 'off'

    def execute(self):
        cfg = train_config(self)
        cfg.train(cfg)


def main():
    p = ArgumentParser()
    p.add_arguments(TrainOptions, dest='TrainOptions')
#     for patch_size in [1,32]:
#         for wavelet_level in [1,2,3,4,5,6,7,8,9]:    
#             try:
    in_ch, out_ch = 1, 14
    model_params = "effnetv2:pretrained:"+str(in_ch)+":"+str(out_ch)    
    
#     model_params = "waveletmlp:300:1:14:"+str(patch_size)+":"+str(wavelet_level)+":1:2"
    exp_id = 'model_'+model_params+'_in_ch_'+str(in_ch)+'out_ch_'+str(out_ch)#+'_patch_size_' + str(patch_size) + '_level_' + str(wavelet_level)
    args = p.parse_args(["--dset", "chexpert_small:.01:.01", "--opt", "Adam:lr=0.001", "--lossfn", "chexpert_uignore", "--model", model_params, "--loss_reg", "none","--experiment_id",exp_id]).TrainOptions

    print(args)
    cfg = train_config(args)

# python deepfix/train.py --dset chexpert_small:.01:.01 --opt Adam:lr=0.001 --lossfn chexpert_uignore --model waveletmlp:300:1:14:7:1:1:2 --loss_reg none    

    if args.prune != 'off':
        assert args.prune.startswith('ChannelPrune:')
        raise NotImplementedError('code is a bit hardcoded, so it is not available without hacking on it.')
        print(args.prune)
        from explainfix import channelprune
        from deepfix.weight_saliency import costfn_multiclass
        a = sum([x.numel() for x in cfg.model.parameters()])
        channelprune(cfg.model, pct=5, grad_cost_fn=costfn_multiclass,
                     loader=cfg.train_loader, device=cfg.device, num_minibatches=10)
        b = sum([x.numel() for x in cfg.model.parameters()])
        assert a/b != 1
        print(f'done channelpruning.  {a/b}')

    cfg.train(cfg)
#             except Exception as e:
#                 print("=================================================================================================")
#                 print(e)
#                 print("=================================================================================================")
            
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    #  import IPython ; IPython.embed() ; import sys ; sys.exit()

    #  with T.profiler.profile(
    #      activities=[
    #          T.profiler.ProfilerActivity.CPU,
    #          T.profiler.ProfilerActivity.CUDA,
    #      ], with_modules=True,
    #  ) as p:
    #      cfg.train(cfg)
    #  print(p.key_averages().table(
    #      sort_by="self_cuda_time_total", row_limit=-1))


if __name__ == "__main__":
    main()
# Out:
# TrainOptions(epochs=50, start_epoch=0, device='cuda', dset='chexpert_small:.01:.01', opt='Adam:lr=0.001', lossfn='chexpert_uignore', loss_reg='none', model='effnetv2:untrained:1:14', deepfix='off', experiment_id='model_effnetv2:untrained:1:14_in_ch_1out_ch_14', prune='off')
# Checkpoint ./results/model_effnetv2:untrained:1:14_in_ch_1out_ch_14/checkpoints/epoch_0.pth
# 100%|██████████| 149/149 [00:45<00:00,  3.26it/s]
# 100%|██████████| 149/149 [00:49<00:00,  3.02it/s]
# 100%|██████████| 16/16 [00:06<00:00,  2.30it/s]
# INFO:simplepytorch.logging_tools:DataLogger writing to file: /ocean/projects/cie160013p/elvinj/DeepFix/deepfix/results/model_effnetv2:untrained:1:14_in_ch_1out_ch_14/log/20220130T025116.066347_perf.csv
# epoch:    0, seconds_training_epoch: nan
# 	TRAIN RESULTS: train_Loss:  103.27892, train_Num Samples:  2234.00000, train_MCC No Finding:  nan, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  nan, train_MCC Lung Opacity:  0.00597, train_MCC Lung Lesion:  nan, train_MCC Edema:  nan, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  0.10921, train_MCC Pleural Effusion:  nan, train_MCC Pleural Other:  nan, train_MCC Fracture:  0.00618, train_MCC Support Devices:  nan, train_MCC AVG:  nan, train_Precision No Finding:  0.00000, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.50769, train_Precision Lung Lesion:  0.04024, train_Precision Edema:  0.00000, train_Precision Consolidation:  0.07926, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.62500, train_Precision Pleural Effusion:  0.00000, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.03813, train_Precision Support Devices:  0.00000, train_Precision AVG:  0.09217, train_Recall No Finding:  0.00000, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.03075, train_Recall Lung Lesion:  1.00000, train_Recall Edema:  0.00000, train_Recall Consolidation:  1.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.02392, train_Recall Pleural Effusion:  0.00000, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.69880, train_Recall Support Devices:  0.00000, train_Recall AVG:  0.19668, train_F1 No Finding:  nan, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.05800, train_F1 Lung Lesion:  0.07736, train_F1 Edema:  nan, train_F1 Consolidation:  0.14688, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  0.04608, train_F1 Pleural Effusion:  nan, train_F1 Pleural Other:  nan, train_F1 Fracture:  0.07232, train_F1 Support Devices:  nan, train_F1 AVG:  nan, train_Acc No Finding:  0.89570, train_Acc Enlarged Cardiomediastinum:  0.94822, train_Acc Cardiomegaly:  0.88151, train_Acc Lung Opacity:  0.50983, train_Acc Lung Lesion:  0.04024, train_Acc Edema:  0.74976, train_Acc Consolidation:  0.07926, train_Acc Pneumonia:  0.97112, train_Acc Atelectasis:  0.83039, train_Acc Pneumothorax:  0.90599, train_Acc Pleural Effusion:  0.59063, train_Acc Pleural Other:  0.98139, train_Acc Fracture:  0.33063, train_Acc Support Devices:  0.49190, train_Acc AVG:  0.65761, train_BAcc No Finding:  0.50000, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50000, train_BAcc Lung Opacity:  0.50101, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.50000, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.51121, train_BAcc Pleural Effusion:  0.50000, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50758, train_BAcc Support Devices:  0.50000, train_BAcc AVG:  0.50141
# 	VAL RESULTS: val_Loss:  103.27892, val_Num Samples:  2234.00000, val_MCC No Finding:  nan, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  nan, val_MCC Lung Opacity:  0.04496, val_MCC Lung Lesion:  0.01194, val_MCC Edema:  nan, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax: -0.01349, val_MCC Pleural Effusion:  nan, val_MCC Pleural Other:  nan, val_MCC Fracture: -0.00912, val_MCC Support Devices:  nan, val_MCC AVG:  nan, val_Precision No Finding:  0.00000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.00000, val_Precision Lung Opacity:  0.60526, val_Precision Lung Lesion:  0.03801, val_Precision Edema:  0.00000, val_Precision Consolidation:  0.08087, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.00000, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.03667, val_Precision Support Devices:  0.00000, val_Precision AVG:  0.05434, val_Recall No Finding:  0.00000, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.00000, val_Recall Lung Opacity:  0.04327, val_Recall Lung Lesion:  1.00000, val_Recall Edema:  0.00000, val_Recall Consolidation:  1.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  0.00000, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.71429, val_Recall Support Devices:  0.00000, val_Recall AVG:  0.19697, val_F1 No Finding:  nan, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  nan, val_F1 Lung Opacity:  0.08077, val_F1 Lung Lesion:  0.07323, val_F1 Edema:  nan, val_F1 Consolidation:  0.14965, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  nan, val_F1 Pleural Other:  nan, val_F1 Fracture:  0.06977, val_F1 Support Devices:  nan, val_F1 AVG:  nan, val_Acc No Finding:  0.90286, val_Acc Enlarged Cardiomediastinum:  0.95240, val_Acc Cardiomegaly:  0.87687, val_Acc Lung Opacity:  0.52038, val_Acc Lung Lesion:  0.04148, val_Acc Edema:  0.74010, val_Acc Consolidation:  0.08087, val_Acc Pneumonia:  0.96964, val_Acc Atelectasis:  0.81780, val_Acc Pneumothorax:  0.90731, val_Acc Pleural Effusion:  0.57331, val_Acc Pleural Other:  0.98545, val_Acc Fracture:  0.28154, val_Acc Support Devices:  0.48290, val_Acc AVG:  0.65235, val_BAcc No Finding:  0.50000, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50000, val_BAcc Lung Opacity:  0.50824, val_BAcc Lung Lesion:  0.50187, val_BAcc Edema:  0.50000, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.49900, val_BAcc Pleural Effusion:  0.50000, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.48943, val_BAcc Support Devices:  0.50000, val_BAcc AVG:  0.49990
# 	TEST RESULTS: test_Loss:  11.09036, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity:  0.13680, test_MCC Lung Lesion:  nan, test_MCC Edema:  nan, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  nan, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  nan, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.00000, test_Precision Lung Opacity:  1.00000, test_Precision Lung Lesion:  0.00427, test_Precision Edema:  0.00000, test_Precision Consolidation:  0.14103, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.00000, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.00000, test_Precision AVG:  0.08181, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.00000, test_Recall Lung Opacity:  0.03968, test_Recall Lung Lesion:  1.00000, test_Recall Edema:  0.00000, test_Recall Consolidation:  1.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.00000, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.00000, test_Recall AVG:  0.14569, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  nan, test_F1 Lung Opacity:  0.07634, test_F1 Lung Lesion:  0.00851, test_F1 Edema:  nan, test_F1 Consolidation:  0.24719, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  nan, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  nan, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.48291, test_Acc Lung Lesion:  0.00427, test_Acc Edema:  0.80769, test_Acc Consolidation:  0.14103, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.71368, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  0.20940, test_Acc Support Devices:  0.54274, test_Acc AVG:  0.61203, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.51984, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.50000, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.50000, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.10470, test_BAcc Support Devices:  0.50000, test_BAcc AVG:  0.47318
# 100%|██████████| 149/149 [01:27<00:00,  1.71it/s]
# 100%|██████████| 149/149 [00:51<00:00,  2.89it/s]
# 100%|██████████| 16/16 [00:07<00:00,  2.20it/s]
# epoch:    1, seconds_training_epoch: 87.0874
# 	TRAIN RESULTS: train_Loss:  55.43298, train_Num Samples:  2234.00000, train_MCC No Finding: -0.01251, train_MCC Enlarged Cardiomediastinum: -0.00721, train_MCC Cardiomegaly: -0.01576, train_MCC Lung Opacity:  0.08349, train_MCC Lung Lesion: -0.01309, train_MCC Edema:  0.09796, train_MCC Consolidation:  0.02266, train_MCC Pneumonia: -0.00382, train_MCC Atelectasis: -0.01812, train_MCC Pneumothorax: -0.01196, train_MCC Pleural Effusion:  0.15969, train_MCC Pleural Other:  nan, train_MCC Fracture:  0.07323, train_MCC Support Devices:  0.19805, train_MCC AVG:  nan, train_Precision No Finding:  0.00000, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.53092, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.42609, train_Precision Consolidation:  0.15385, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.00000, train_Precision Pleural Effusion:  0.55947, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.50000, train_Precision Support Devices:  0.59211, train_Precision AVG:  0.19732, train_Recall No Finding:  0.00000, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.56011, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.09369, train_Recall Consolidation:  0.01299, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.00000, train_Recall Pleural Effusion:  0.29364, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.01205, train_Recall Support Devices:  0.67759, train_Recall AVG:  0.11786, train_F1 No Finding:  nan, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.54512, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.15361, train_F1 Consolidation:  0.02395, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  nan, train_F1 Pleural Effusion:  0.38514, train_F1 Pleural Other:  nan, train_F1 Fracture:  0.02353, train_F1 Support Devices:  0.63197, train_F1 AVG:  nan, train_Acc No Finding:  0.89436, train_Acc Enlarged Cardiomediastinum:  0.94727, train_Acc Cardiomegaly:  0.87967, train_Acc Lung Opacity:  0.54138, train_Acc Lung Lesion:  0.95570, train_Acc Edema:  0.74163, train_Acc Consolidation:  0.91611, train_Acc Pneumonia:  0.97063, train_Acc Atelectasis:  0.82879, train_Acc Pneumothorax:  0.90372, train_Acc Pleural Effusion:  0.61619, train_Acc Pleural Other:  0.98139, train_Acc Fracture:  0.96266, train_Acc Support Devices:  0.59901, train_Acc AVG:  0.83846, train_BAcc No Finding:  0.49925, train_BAcc Enlarged Cardiomediastinum:  0.49950, train_BAcc Cardiomegaly:  0.49895, train_BAcc Lung Opacity:  0.54173, train_BAcc Lung Lesion:  0.49788, train_BAcc Edema:  0.52579, train_BAcc Consolidation:  0.50342, train_BAcc Pneumonia:  0.49975, train_BAcc Atelectasis:  0.49903, train_BAcc Pneumothorax:  0.49925, train_BAcc Pleural Effusion:  0.56669, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50579, train_BAcc Support Devices:  0.59772, train_BAcc AVG:  0.51677
# 	VAL RESULTS: val_Loss:  54.40995, val_Num Samples:  2234.00000, val_MCC No Finding:  nan, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  nan, val_MCC Lung Opacity:  0.16836, val_MCC Lung Lesion:  nan, val_MCC Edema:  0.09694, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  nan, val_MCC Pleural Effusion:  0.19092, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.22519, val_MCC AVG:  nan, val_Precision No Finding:  0.00000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.00000, val_Precision Lung Opacity:  0.57889, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.56098, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.63388, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.63250, val_Precision AVG:  0.17188, val_Recall No Finding:  0.00000, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.00000, val_Recall Lung Opacity:  0.54186, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.04220, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  0.25551, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.59617, val_Recall AVG:  0.10255, val_F1 No Finding:  nan, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  nan, val_F1 Lung Opacity:  0.55977, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.07850, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  0.36421, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.61380, val_F1 AVG:  nan, val_Acc No Finding:  0.90286, val_Acc Enlarged Cardiomediastinum:  0.95240, val_Acc Cardiomegaly:  0.87687, val_Acc Lung Opacity:  0.58497, val_Acc Lung Lesion:  0.96213, val_Acc Edema:  0.74249, val_Acc Consolidation:  0.91913, val_Acc Pneumonia:  0.96964, val_Acc Atelectasis:  0.81780, val_Acc Pneumothorax:  0.90913, val_Acc Pleural Effusion:  0.61936, val_Acc Pleural Other:  0.98545, val_Acc Fracture:  0.96228, val_Acc Support Devices:  0.61206, val_Acc AVG:  0.84404, val_BAcc No Finding:  0.50000, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50000, val_BAcc Lung Opacity:  0.58388, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.51530, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50000, val_BAcc Pleural Effusion:  0.57284, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.61262, val_BAcc AVG:  0.52033
# 	TEST RESULTS: test_Loss:  7.47589, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity:  0.29679, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.13716, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.12362, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.23841, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.00000, test_Precision Lung Opacity:  0.73256, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.66667, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.42424, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.59596, test_Precision AVG:  0.17282, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.00000, test_Recall Lung Opacity:  0.50000, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.04444, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.20896, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.55140, test_Recall AVG:  0.09320, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  nan, test_F1 Lung Opacity:  0.59434, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.08333, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.28000, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.57282, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.63248, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.81197, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.69231, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.62393, test_Acc AVG:  0.80586, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.64352, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.51958, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.54759, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.61822, test_BAcc AVG:  0.52349
# 100%|██████████| 149/149 [01:31<00:00,  1.62it/s]
# 100%|██████████| 149/149 [00:58<00:00,  2.55it/s]
# 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
# epoch:    2, seconds_training_epoch: 91.7281
# 	TRAIN RESULTS: train_Loss:  52.66856, train_Num Samples:  2234.00000, train_MCC No Finding:  0.04293, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  nan, train_MCC Lung Opacity:  0.19244, train_MCC Lung Lesion:  nan, train_MCC Edema:  0.17738, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  nan, train_MCC Pleural Effusion:  0.26065, train_MCC Pleural Other:  nan, train_MCC Fracture:  nan, train_MCC Support Devices:  0.22015, train_MCC AVG:  nan, train_Precision No Finding:  0.30000, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.58732, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.50282, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.00000, train_Precision Pleural Effusion:  0.59850, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.60613, train_Precision AVG:  0.18534, train_Recall No Finding:  0.01288, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.59553, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.17017, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.00000, train_Recall Pleural Effusion:  0.46012, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.66519, train_Recall AVG:  0.13599, train_F1 No Finding:  0.02469, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.59139, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.25429, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  nan, train_F1 Pleural Effusion:  0.52026, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.63429, train_F1 AVG:  nan, train_Acc No Finding:  0.89391, train_Acc Enlarged Cardiomediastinum:  0.94822, train_Acc Cardiomegaly:  0.88151, train_Acc Lung Opacity:  0.59625, train_Acc Lung Lesion:  0.95976, train_Acc Edema:  0.75024, train_Acc Consolidation:  0.92074, train_Acc Pneumonia:  0.97112, train_Acc Atelectasis:  0.83039, train_Acc Pneumothorax:  0.90509, train_Acc Pleural Effusion:  0.65263, train_Acc Pleural Other:  0.98139, train_Acc Fracture:  0.96266, train_Acc Support Devices:  0.61026, train_Acc AVG:  0.84744, train_BAcc No Finding:  0.50469, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50000, train_BAcc Lung Opacity:  0.59624, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.55701, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.50000, train_BAcc Pleural Effusion:  0.62309, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50000, train_BAcc Support Devices:  0.60936, train_BAcc AVG:  0.52788
# 	VAL RESULTS: val_Loss:  54.50272, val_Num Samples:  2234.00000, val_MCC No Finding:  0.06452, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  nan, val_MCC Lung Opacity:  0.18263, val_MCC Lung Lesion:  nan, val_MCC Edema:  0.19258, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  nan, val_MCC Pleural Effusion:  0.29156, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.19711, val_MCC AVG:  nan, val_Precision No Finding:  1.00000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.00000, val_Precision Lung Opacity:  0.62791, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.57447, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.68588, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.67887, val_Precision AVG:  0.25479, val_Recall No Finding:  0.00461, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.00000, val_Recall Lung Opacity:  0.38100, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.14862, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  0.37996, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.35509, val_Recall AVG:  0.09066, val_F1 No Finding:  0.00917, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  nan, val_F1 Lung Opacity:  0.47424, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.23615, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  0.48901, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.46629, val_F1 AVG:  nan, val_Acc No Finding:  0.90331, val_Acc Enlarged Cardiomediastinum:  0.95240, val_Acc Cardiomegaly:  0.87687, val_Acc Lung Opacity:  0.58864, val_Acc Lung Lesion:  0.96213, val_Acc Edema:  0.75012, val_Acc Consolidation:  0.91913, val_Acc Pneumonia:  0.96964, val_Acc Atelectasis:  0.81780, val_Acc Pneumothorax:  0.90913, val_Acc Pleural Effusion:  0.66118, val_Acc Pleural Other:  0.98545, val_Acc Fracture:  0.96228, val_Acc Support Devices:  0.57966, val_Acc AVG:  0.84555, val_BAcc No Finding:  0.50230, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50000, val_BAcc Lung Opacity:  0.58336, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.55498, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50000, val_BAcc Pleural Effusion:  0.62522, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.58761, val_BAcc AVG:  0.52525
# 	TEST RESULTS: test_Loss:  7.81881, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity:  0.37856, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.23258, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.30220, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.10714, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.00000, test_Precision Lung Opacity:  0.91489, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.71429, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.61765, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.56818, test_Precision AVG:  0.20107, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.00000, test_Recall Lung Opacity:  0.34127, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.11111, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.31343, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.23364, test_Recall AVG:  0.07139, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  nan, test_F1 Lung Opacity:  0.49711, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.19231, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.41584, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.33113, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.62821, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.82051, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.74786, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.56838, test_Acc AVG:  0.80617, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.65212, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.55026, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.61779, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.54202, test_BAcc AVG:  0.52587
# 100%|██████████| 149/149 [01:23<00:00,  1.78it/s]
# 100%|██████████| 149/149 [00:52<00:00,  2.82it/s]
# 100%|██████████| 16/16 [00:07<00:00,  2.27it/s]
# epoch:    3, seconds_training_epoch: 83.6134
# 	TRAIN RESULTS: train_Loss:  52.23975, train_Num Samples:  2234.00000, train_MCC No Finding: -0.00722, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  nan, train_MCC Lung Opacity:  0.19841, train_MCC Lung Lesion:  nan, train_MCC Edema:  0.19424, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  nan, train_MCC Pleural Effusion:  0.28041, train_MCC Pleural Other:  nan, train_MCC Fracture:  nan, train_MCC Support Devices:  0.25591, train_MCC AVG:  nan, train_Precision No Finding:  0.00000, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.58797, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.52514, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.00000, train_Precision Pleural Effusion:  0.61261, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.61515, train_Precision AVG:  0.16721, train_Recall No Finding:  0.00000, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.61044, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.17973, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.00000, train_Recall Pleural Effusion:  0.47168, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.71213, train_Recall AVG:  0.14100, train_F1 No Finding:  nan, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.59899, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.26781, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  nan, train_F1 Pleural Effusion:  0.53299, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.66010, train_F1 AVG:  nan, train_Acc No Finding:  0.89526, train_Acc Enlarged Cardiomediastinum:  0.94822, train_Acc Cardiomegaly:  0.88151, train_Acc Lung Opacity:  0.59899, train_Acc Lung Lesion:  0.95976, train_Acc Edema:  0.75407, train_Acc Consolidation:  0.92074, train_Acc Pneumonia:  0.97112, train_Acc Atelectasis:  0.83039, train_Acc Pneumothorax:  0.90509, train_Acc Pleural Effusion:  0.66162, train_Acc Pleural Other:  0.98139, train_Acc Fracture:  0.96266, train_Acc Support Devices:  0.62736, train_Acc AVG:  0.84987, train_BAcc No Finding:  0.49975, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50000, train_BAcc Lung Opacity:  0.59920, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.56274, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.50000, train_BAcc Pleural Effusion:  0.63247, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50000, train_BAcc Support Devices:  0.62597, train_BAcc AVG:  0.53001
# 	VAL RESULTS: val_Loss:  51.37823, val_Num Samples:  2234.00000, val_MCC No Finding:  nan, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  nan, val_MCC Lung Opacity:  0.24295, val_MCC Lung Lesion:  nan, val_MCC Edema:  0.18739, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  nan, val_MCC Pleural Effusion:  0.30510, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.27453, val_MCC AVG:  nan, val_Precision No Finding:  0.00000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.00000, val_Precision Lung Opacity:  0.62633, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.56835, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.66612, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.70000, val_Precision AVG:  0.18291, val_Recall No Finding:  0.00000, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.00000, val_Recall Lung Opacity:  0.55503, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.14495, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  0.44383, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.48738, val_Recall AVG:  0.11651, val_F1 No Finding:  nan, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  nan, val_F1 Lung Opacity:  0.58853, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.23099, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  0.53272, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.57465, val_F1 AVG:  nan, val_Acc No Finding:  0.90286, val_Acc Enlarged Cardiomediastinum:  0.95240, val_Acc Cardiomegaly:  0.87687, val_Acc Lung Opacity:  0.62208, val_Acc Lung Lesion:  0.96213, val_Acc Edema:  0.74917, val_Acc Consolidation:  0.91913, val_Acc Pneumonia:  0.96964, val_Acc Atelectasis:  0.81780, val_Acc Pneumothorax:  0.90913, val_Acc Pleural Effusion:  0.66776, val_Acc Pleural Other:  0.98545, val_Acc Fracture:  0.96228, val_Acc Support Devices:  0.62691, val_Acc AVG:  0.85169, val_BAcc No Finding:  0.50000, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50000, val_BAcc Lung Opacity:  0.62037, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.55315, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50000, val_BAcc Pleural Effusion:  0.63913, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.63185, val_BAcc AVG:  0.53175
# 	TEST RESULTS: test_Loss:  7.41474, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity:  0.41421, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.26385, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.38268, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.19121, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.00000, test_Precision Lung Opacity:  0.87500, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.83333, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.70588, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.64000, test_Precision AVG:  0.21816, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.00000, test_Recall Lung Opacity:  0.44444, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.11111, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.35821, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.29907, test_Recall AVG:  0.08663, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  nan, test_F1 Lung Opacity:  0.58947, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.19608, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.47525, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.40764, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.66667, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.82479, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.77350, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.60256, test_Acc AVG:  0.81349, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.68519, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.55291, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.64916, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.57867, test_BAcc AVG:  0.53328
# 100%|██████████| 149/149 [01:22<00:00,  1.80it/s]
# 100%|██████████| 149/149 [00:53<00:00,  2.78it/s]
# 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
# epoch:    4, seconds_training_epoch: 82.7393
# 	TRAIN RESULTS: train_Loss:  52.03650, train_Num Samples:  2234.00000, train_MCC No Finding:  0.05507, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  nan, train_MCC Lung Opacity:  0.19769, train_MCC Lung Lesion:  nan, train_MCC Edema:  0.20491, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  nan, train_MCC Pleural Effusion:  0.29946, train_MCC Pleural Other:  nan, train_MCC Fracture:  nan, train_MCC Support Devices:  0.24771, train_MCC AVG:  nan, train_Precision No Finding:  0.33333, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.59142, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.52850, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.00000, train_Precision Pleural Effusion:  0.61571, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.61162, train_Precision AVG:  0.19147, train_Recall No Finding:  0.01717, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.59087, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.19503, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.00000, train_Recall Pleural Effusion:  0.50751, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.70859, train_Recall AVG:  0.14423, train_F1 No Finding:  0.03265, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.59114, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.28492, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  nan, train_F1 Pleural Effusion:  0.55640, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.65654, train_F1 AVG:  nan, train_Acc No Finding:  0.89391, train_Acc Enlarged Cardiomediastinum:  0.94822, train_Acc Cardiomegaly:  0.88151, train_Acc Lung Opacity:  0.59899, train_Acc Lung Lesion:  0.95976, train_Acc Edema:  0.75502, train_Acc Consolidation:  0.92074, train_Acc Pneumonia:  0.97112, train_Acc Atelectasis:  0.83039, train_Acc Pneumothorax:  0.90509, train_Acc Pleural Effusion:  0.66872, train_Acc Pleural Other:  0.98139, train_Acc Fracture:  0.96266, train_Acc Support Devices:  0.62331, train_Acc AVG:  0.85006, train_BAcc No Finding:  0.50658, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50000, train_BAcc Lung Opacity:  0.59884, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.56848, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.50000, train_BAcc Pleural Effusion:  0.64398, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50000, train_BAcc Support Devices:  0.62191, train_BAcc AVG:  0.53141
# 	VAL RESULTS: val_Loss:  51.24258, val_Num Samples:  2234.00000, val_MCC No Finding:  0.13422, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  nan, val_MCC Lung Opacity:  0.23851, val_MCC Lung Lesion:  nan, val_MCC Edema:  0.28861, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  nan, val_MCC Pleural Effusion:  0.33655, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.29627, val_MCC AVG:  nan, val_Precision No Finding:  0.52632, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.00000, val_Precision Lung Opacity:  0.55975, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.57586, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.61065, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.62934, val_Precision AVG:  0.20728, val_Recall No Finding:  0.04608, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.00000, val_Recall Lung Opacity:  0.83725, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.30642, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  0.64427, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.77285, val_Recall AVG:  0.18621, val_F1 No Finding:  0.08475, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  nan, val_F1 Lung Opacity:  0.67094, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.40000, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  0.62701, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.69375, val_F1 AVG:  nan, val_Acc No Finding:  0.90331, val_Acc Enlarged Cardiomediastinum:  0.95240, val_Acc Cardiomegaly:  0.87687, val_Acc Lung Opacity:  0.60009, val_Acc Lung Lesion:  0.96213, val_Acc Edema:  0.76109, val_Acc Consolidation:  0.91913, val_Acc Pneumonia:  0.96964, val_Acc Atelectasis:  0.81780, val_Acc Pneumothorax:  0.90913, val_Acc Pleural Effusion:  0.67293, val_Acc Pleural Other:  0.98545, val_Acc Fracture:  0.96228, val_Acc Support Devices:  0.64716, val_Acc AVG:  0.85282, val_BAcc No Finding:  0.52081, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50000, val_BAcc Lung Opacity:  0.60613, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.61358, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50000, val_BAcc Pleural Effusion:  0.66927, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.64271, val_BAcc AVG:  0.53946
# 	TEST RESULTS: test_Loss:  7.02242, test_Num Samples:  234.00000, test_MCC No Finding:  0.14850, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity:  0.46992, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.38336, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.38394, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.25128, test_MCC AVG:  nan, test_Precision No Finding:  0.50000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.00000, test_Precision Lung Opacity:  0.71053, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.75000, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.54930, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.56923, test_Precision AVG:  0.21993, test_Recall No Finding:  0.07895, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.00000, test_Recall Lung Opacity:  0.85714, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.26667, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.58209, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.69159, test_Recall AVG:  0.17689, test_F1 No Finding:  0.13636, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  nan, test_F1 Lung Opacity:  0.77698, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.39344, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.56522, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.62447, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.73504, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.84188, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.74359, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.61966, test_Acc AVG:  0.81868, test_BAcc No Finding:  0.53182, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.72487, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.62275, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.69524, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.62532, test_BAcc AVG:  0.55000
# 100%|██████████| 149/149 [01:22<00:00,  1.81it/s]
# 100%|██████████| 149/149 [00:55<00:00,  2.71it/s]
# 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
# epoch:    5, seconds_training_epoch: 82.4535
# ...
# 	VAL RESULTS: val_Loss:  61.92283, val_Num Samples:  2234.00000, val_MCC No Finding:  0.32084, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  0.17180, val_MCC Lung Opacity:  0.20977, val_MCC Lung Lesion:  nan, val_MCC Edema:  0.28423, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  0.00933, val_MCC Pleural Effusion:  0.37048, val_MCC Pleural Other: -0.00259, val_MCC Fracture:  nan, val_MCC Support Devices:  0.27284, val_MCC AVG:  nan, val_Precision No Finding:  0.35448, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.31737, val_Precision Lung Opacity:  0.60141, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.47290, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.11538, val_Precision Pleural Effusion:  0.67843, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.64921, val_Precision AVG:  0.22780, val_Recall No Finding:  0.43779, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.20076, val_Recall Lung Opacity:  0.56350, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.46422, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.01500, val_Recall Pleural Effusion:  0.55066, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.64752, val_Recall AVG:  0.20567, val_F1 No Finding:  0.39175, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  0.24594, val_F1 Lung Opacity:  0.58184, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.46852, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  0.02655, val_F1 Pleural Effusion:  0.60790, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.64837, val_F1 AVG:  nan, val_Acc No Finding:  0.86795, val_Acc Enlarged Cardiomediastinum:  0.95240, val_Acc Cardiomegaly:  0.84841, val_Acc Lung Opacity:  0.60559, val_Acc Lung Lesion:  0.96213, val_Acc Edema:  0.72628, val_Acc Consolidation:  0.91913, val_Acc Pneumonia:  0.96964, val_Acc Atelectasis:  0.81780, val_Acc Pneumothorax:  0.90005, val_Acc Pleural Effusion:  0.69690, val_Acc Pleural Other:  0.98499, val_Acc Fracture:  0.96228, val_Acc Support Devices:  0.63681, val_Acc AVG:  0.84645, val_BAcc No Finding:  0.67601, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.57006, val_BAcc Lung Opacity:  0.60452, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.64126, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50175, val_BAcc Pleural Effusion:  0.67820, val_BAcc Pleural Other:  0.49977, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.63643, val_BAcc AVG:  0.55771
# 	TEST RESULTS: test_Loss:  8.87631, test_Num Samples:  234.00000, test_MCC No Finding:  0.23293, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  0.12467, test_MCC Lung Opacity:  0.36006, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.26961, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax: -0.01747, test_MCC Pleural Effusion:  0.38657, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.17095, test_MCC AVG:  nan, test_Precision No Finding:  0.34091, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.54545, test_Precision Lung Opacity:  0.78750, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.45455, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.64444, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.53543, test_Precision AVG:  0.23631, test_Recall No Finding:  0.39474, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.08824, test_Recall Lung Opacity:  0.50000, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.33333, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.43284, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.63551, test_Recall AVG:  0.17033, test_F1 No Finding:  0.36585, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  0.15190, test_F1 Lung Opacity:  0.61165, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.38462, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.51786, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.58120, test_F1 AVG:  nan, test_Acc No Finding:  0.77778, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.71368, test_Acc Lung Opacity:  0.65812, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.79487, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.95726, test_Acc Pleural Effusion:  0.76923, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.58120, test_Acc AVG:  0.80433, test_BAcc No Finding:  0.62339, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.52906, test_BAcc Lung Opacity:  0.67130, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.61905, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.49558, test_BAcc Pleural Effusion:  0.66851, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.58547, test_BAcc AVG:  0.54945
# 100%|██████████| 149/149 [01:09<00:00,  2.15it/s]
# 100%|██████████| 149/149 [01:00<00:00,  2.47it/s]
# 100%|██████████| 16/16 [00:06<00:00,  2.39it/s]
# epoch:   50, seconds_training_epoch: 69.2022
# 	TRAIN RESULTS: train_Loss:  35.73196, train_Num Samples:  2234.00000, train_MCC No Finding:  0.76343, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  0.61839, train_MCC Lung Opacity:  0.45143, train_MCC Lung Lesion:  nan, train_MCC Edema:  0.58194, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  0.34288, train_MCC Pleural Effusion:  0.78911, train_MCC Pleural Other:  nan, train_MCC Fracture:  nan, train_MCC Support Devices:  0.59333, train_MCC AVG:  nan, train_Precision No Finding:  0.84236, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.77297, train_Precision Lung Opacity:  0.69061, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.73009, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.61250, train_Precision Pleural Effusion:  0.88235, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.80633, train_Precision AVG:  0.38123, train_Recall No Finding:  0.73391, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.55642, train_Recall Lung Opacity:  0.78844, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.63098, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.23445, train_Recall Pleural Effusion:  0.86705, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.78919, train_Recall AVG:  0.32860, train_F1 No Finding:  0.78440, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  0.64706, train_F1 Lung Opacity:  0.73629, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.67692, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  0.33910, train_F1 Pleural Effusion:  0.87464, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.79767, train_F1 AVG:  nan, train_Acc No Finding:  0.95792, train_Acc Enlarged Cardiomediastinum:  0.94822, train_Acc Cardiomegaly:  0.92808, train_Acc Lung Opacity:  0.72291, train_Acc Lung Lesion:  0.95976, train_Acc Edema:  0.84928, train_Acc Consolidation:  0.92074, train_Acc Pneumonia:  0.97112, train_Acc Atelectasis:  0.83039, train_Acc Pneumothorax:  0.91326, train_Acc Pleural Effusion:  0.89825, train_Acc Pleural Other:  0.98139, train_Acc Fracture:  0.96266, train_Acc Support Devices:  0.79658, train_Acc AVG:  0.90290, train_BAcc No Finding:  0.85896, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.76723, train_BAcc Lung Opacity:  0.72411, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.77656, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.60945, train_BAcc Pleural Effusion:  0.89346, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50000, train_BAcc Support Devices:  0.79670, train_BAcc AVG:  0.63760
# 	VAL RESULTS: val_Loss:  60.63798, val_Num Samples:  2234.00000, val_MCC No Finding:  0.26327, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  0.21010, val_MCC Lung Opacity:  0.19661, val_MCC Lung Lesion:  0.04037, val_MCC Edema:  0.29763, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis: -0.01528, val_MCC Pneumothorax:  0.09563, val_MCC Pleural Effusion:  0.36554, val_MCC Pleural Other: -0.00367, val_MCC Fracture:  nan, val_MCC Support Devices:  0.32966, val_MCC AVG:  nan, val_Precision No Finding:  0.37975, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.36145, val_Precision Lung Opacity:  0.55624, val_Precision Lung Lesion:  0.20000, val_Precision Edema:  0.47748, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.18497, val_Precision Pleural Effusion:  0.63747, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.66531, val_Precision AVG:  0.24733, val_Recall No Finding:  0.27650, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.22727, val_Recall Lung Opacity:  0.76294, val_Recall Lung Lesion:  0.01190, val_Recall Edema:  0.48624, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.16000, val_Recall Pleural Effusion:  0.63326, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.71105, val_Recall AVG:  0.23351, val_F1 No Finding:  0.32000, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  0.27907, val_F1 Lung Opacity:  0.64340, val_F1 Lung Lesion:  0.02247, val_F1 Edema:  0.48182, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  0.17158, val_F1 Pleural Effusion:  0.63536, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.68742, val_F1 AVG:  nan, val_Acc No Finding:  0.88585, val_Acc Enlarged Cardiomediastinum:  0.95240, val_Acc Cardiomegaly:  0.85541, val_Acc Lung Opacity:  0.58818, val_Acc Lung Lesion:  0.96078, val_Acc Edema:  0.72818, val_Acc Consolidation:  0.91913, val_Acc Pneumonia:  0.96964, val_Acc Atelectasis:  0.81675, val_Acc Pneumothorax:  0.85961, val_Acc Pleural Effusion:  0.68985, val_Acc Pleural Other:  0.98454, val_Acc Fracture:  0.96228, val_Acc Support Devices:  0.66562, val_Acc AVG:  0.84559, val_BAcc No Finding:  0.61396, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.58544, val_BAcc Lung Opacity:  0.59263, val_BAcc Lung Lesion:  0.50502, val_BAcc Edema:  0.64969, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.49936, val_BAcc Pneumothorax:  0.54477, val_BAcc Pleural Effusion:  0.68261, val_BAcc Pleural Other:  0.49954, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.66401, val_BAcc AVG:  0.55979
# 	TEST RESULTS: test_Loss:  8.42142, test_Num Samples:  234.00000, test_MCC No Finding:  0.27227, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  0.15603, test_MCC Lung Opacity:  0.45741, test_MCC Lung Lesion: -0.00429, test_MCC Edema:  0.24254, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax: -0.04924, test_MCC Pleural Effusion:  0.35930, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.27243, test_MCC AVG:  nan, test_Precision No Finding:  0.41935, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.57143, test_Precision Lung Opacity:  0.74419, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.38298, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.54545, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.58400, test_Precision AVG:  0.23196, test_Recall No Finding:  0.34211, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.11765, test_Recall Lung Opacity:  0.76190, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.40000, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.53731, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.68224, test_Recall AVG:  0.20294, test_F1 No Finding:  0.37681, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  0.19512, test_F1 Lung Opacity:  0.75294, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.39130, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.54135, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.62931, test_F1 AVG:  nan, test_Acc No Finding:  0.81624, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.71795, test_Acc Lung Opacity:  0.73077, test_Acc Lung Lesion:  0.99145, test_Acc Edema:  0.76068, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.90171, test_Acc Pleural Effusion:  0.73932, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.63248, test_Acc AVG:  0.80739, test_BAcc No Finding:  0.62513, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.54075, test_BAcc Lung Opacity:  0.72817, test_BAcc Lung Lesion:  0.49785, test_BAcc Edema:  0.62328, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.46681, test_BAcc Pleural Effusion:  0.67884, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.63640, test_BAcc AVG:  0.55695
# Checkpoint ./results/model_effnetv2:untrained:1:14_in_ch_1out_ch_14/checkpoints/epoch_50.pth
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# MODELS = {
#     ('effnetv2', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_effnetv2(pretrain, int(in_ch), int(out_ch))),
#     ('resnet50', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_resnet('resnet50', pretrain, int(in_ch), int(out_ch))),
#     ('resnet18', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_resnet('resnet18', pretrain, int(in_ch), int(out_ch))),
#     ('efficientnet-b0', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_efficientnetv1('efficientnet-b0', pretrain, int(in_ch), int(out_ch))),
#     ('efficientnet-b1', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_efficientnetv1('efficientnet-b1', pretrain, int(in_ch), int(out_ch))),
#     ('waveletres18', str, str, str): lambda pretrain, in_ch, out_ch: R(
#         pretrain, int(in_ch), int(out_ch)),
#     ('waveletmlp', str, str, str, str, str, str, str): (
#         lambda mlp_channels, in_ch, out_ch, wavelet_levels, patch_size, in_ch_mul, mlp_depth: get_DeepFixEnd2End(
#             int(in_ch), int(out_ch),
#             in_ch_multiplier=int(in_ch_mul), wavelet='db1',
#             wavelet_levels=int(wavelet_levels), wavelet_patch_size=int(patch_size),
#             mlp_depth=int(mlp_depth), mlp_channels=int(mlp_channels),
#             mlp_fix_weights='none', mlp_activation=None)
#         ),

#     #  ('waveletres18v2', str, str, str): lambda pretrain, in_ch, out_ch: (
#         #  DeepFixCompression(levels=8, wavelet='coif1', patch_size=1),
#         #  R2(pretrain, int(in_ch), int(out_ch))),
# }


# class R(T.nn.Module):
#     def __init__(self, pretrain, in_ch, out_ch):
#         super().__init__()
#         self.r = get_resnet('resnet18', pretrain, in_ch, out_ch,)
#         self.dwt = pyw.DWT(J=8, wave='coif1', mode='zero')

#     @staticmethod
#     def wavelet_coefficients_as_tensorimage(approx, detail, normalize=False):
#         B,C = approx.shape[:2]
#         fixed_dims = approx.shape[:-2] # num images in minibatch, num channels, etc
#         output_shape = fixed_dims + (
#             detail[0].shape[-2]*2,  # input img height
#             detail[0].shape[-1]*2)  # input img width
#         im = T.zeros(output_shape, device=approx.device, dtype=approx.dtype)
#         if normalize:
#             norm11 = lambda x: (x / max(x.min()*-1, x.max()))  # into [-1,+1] preserving sign
#             #  approx = norm11(approx)
#         im[..., :approx.shape[-2], :approx.shape[-1]] = approx if approx is not None else 0
#         for level in detail:
#             lh, hl, hh = level.unbind(-3)
#             h,w = lh.shape[-2:]
#             if normalize:
#                 lh, hl, hh = [norm11(x) for x in [lh, hl, hh]]
#             #  im[:h, :w] = approx
#             im[..., 0:h, w:w+w] = lh  # horizontal
#             im[..., h:h+h, :w] = hl  # vertical
#             im[..., h:h+h, w:w+w] = hh  # diagonal
#         return im

#     def forward(self, x):
#         x = self.wavelet_coefficients_as_tensorimage(*self.dwt(x))
#         return self.r(x)


# class R2(T.nn.Module):
#     def __init__(self, pretrain, in_ch, out_ch):
#         super().__init__()
#         self.r = get_resnet('resnet18', pretrain, in_ch, out_ch,)

#     def forward(self, x):
#         B,C,H = x.shape
#         x = x.unsqueeze(-1).repeat(1,1,1,H)
#         return self.r(x)


# class LossCheXpertIdentity(T.nn.Module):
#     def __init__(self, N):
#         super().__init__()
#         self.bce = T.nn.BCEWithLogitsLoss()
#         self.N = N

#     def forward(self, yhat, y):
#         # absolute max possible num patients in chexpert is 223414
#         # but let's just hash them into a smaller number of bins via modulo N
#         assert self.N == yhat.shape[1], \
#                 f'note: model must have {self.N} binary predictions per sample'
#         y_onehot = y.new_zeros(y.shape[0], self.N, dtype=T.float
#                                ).scatter_(1, y.long()%self.N, 1)
#         return self.bce(yhat[:, -1], y_onehot[:, -1])


# class LossCheXpertUignore(T.nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.bce = T.nn.BCEWithLogitsLoss()

#     def forward(self, yhat, y):
#         ignore = (y != 2)  # ignore uncertainty labels
#         return self.bce(yhat[ignore], y[ignore])


# def loss_intelmobileodt(yhat, y):
#     """BCE Loss with class balancing weights.

#     Not sure this actually helps

#     because Type 2 is the hardest class, it
#     has the most samples, and it separates Type 1 from Type 3.  Arguably, Type 2
#     samples are on the decision boundary between Type 1 and 3.
#     Class balancing weights make it harder to focus on class 2.
#     """
#     #  assert y.shape == yhat.shape, 'sanity check'
#     #  assert y.dtype == yhat.dtype, 'sanity check'

#     # class distribution of stage='train'
#     w = T.tensor([249, 781, 450], dtype=y.dtype, device=y.device)
#     w = (w.max() / w).reshape(1, 3)
#     # w can have any of the shapes:  (B,1) or (1,C) or (B,C)
#     #  return T.nn.functional.binary_cross_entropy_with_logits(yhat, y, weight=w)
#     return T.nn.functional.cross_entropy(yhat, y, weight=w)
#     # can't apply focal loss unless do it manually.


# def onehot(y, nclasses):
#     return T.zeros((y.numel(), nclasses), dtype=y.dtype, device=y.device)\
#             .scatter_(1, y.unsqueeze(1), 1)


# def _upsample_pad_minibatch_imgs_to_same_size(batch, target_is_segmentation_mask=False):
#     """a collate function for a dataloader of (x,y) samples.  """
#     shapes = [item[0].shape for item in batch]
#     H = max(h for c,h,w in shapes)
#     W = max(w for c,h,w in shapes)
#     X, Y = [], []
#     for item in batch:
#         h,w = item[0].shape[1:]
#         dh, dw = (H-h), (W-w)
#         padding = (dw//2, dw-dw//2, dh//2, dh-dh//2, )
#         X.append(T.nn.functional.pad(item[0], padding))
#         if target_is_segmentation_mask:
#             Y.append(T.nn.functional.pad(item[1], padding))
#         else:
#             Y.append(item[1])
#     return T.stack(X), T.stack(Y)


# def get_dset_chexpert(train_frac=.8, val_frac=.2, small=False,
#                       labels:str='diagnostic', num_identities=None):
#     """
#     Args:
#         labels:  either "diagnostic" (the 14 classes defined as
#             D.CheXpert.LABELS_DIAGNOSTIC) or "identity" ("patient", "study",
#             "view", "index")
#         small:  whether to use CheXpert_Small dataset (previously downsampled
#             images) or the fully size dataset.
#         num_identities:  used only if labels='identity'.  If
#             num_identities=1000, then all patients get identified as coming
#             from precisely 1 of 1000 bins.

#     Returns:
#         (
#         {'train_dset': ..., 'val_dset': ..., 'test_dset': ...,
#          'train_loader': ..., 'val_loader': ..., 'test_loader': ...
#          },

#         ('Pneumonia', 'Cardiomegaly', ...)  # class names defined by `labels`
#         )
#     """
#     _label_cleanup_dct = dict(D.CheXpert.LABEL_CLEANUP_DICT)
#     if labels == 'diagnostic':
#         class_names = D.CheXpert.LABELS_DIAGNOSTIC
#         for k in class_names:
#             _label_cleanup_dct[k][np.nan] = 0  # remap missing value to negative
#         get_ylabels = lambda dct: \
#                 D.CheXpert.format_labels(dct, labels=class_names).float()
#     elif labels == 'identity':
#         class_names = list(range(num_identities))
#         get_ylabels = lambda dct: \
#                 (D.CheXpert.format_labels(dct, labels=['index']) % num_identities).long()
#     else:
#         raise NotImplementedError(f"unrecognized labels: {labels}")
#     kws = dict(
#         img_transform=tvt.Compose([
#             #  tvt.RandomCrop((512, 512)),
#             tvt.ToTensor(),  # full res 1024x1024 imgs
#         ]),
#         getitem_transform=lambda dct: (dct['image'], get_ylabels(dct)),
#         label_cleanup_dct=_label_cleanup_dct,
#     )
#     if small:
#         kls = D.CheXpert_Small
#     else:
#         kls = D.CheXpert

#     train_dset = kls(dataset_dir="../data/CheXpert-v1.0-small/",use_train_set=True, **kws)  #Edited Elvin

#     N = len(train_dset)
#     if train_frac + val_frac == 1:
#         nsplits = [N - int(N*val_frac), int(N*val_frac), 0]
#     else:
#         a,b = int(N*train_frac), int(N*val_frac)
#         nsplits = [a,b, N-a-b]
#     train_dset, val_dset, _ = T.utils.data.random_split(train_dset, nsplits)
#     test_dset = kls(dataset_dir="../data/CheXpert-v1.0-small/",use_train_set=False, **kws) #Edited Elvin
#     batch_dct = dict(
#         batch_size=15, collate_fn=_upsample_pad_minibatch_imgs_to_same_size,
#         num_workers=int(os.environ.get("num_workers", 4)))  # upsample pad must take time
#     train_loader=DataLoader(train_dset, shuffle=True, **batch_dct)
#     val_loader=DataLoader(val_dset, **batch_dct)
#     test_loader=DataLoader(test_dset, **batch_dct)
#     return (dict(
#         train_dset=train_dset, val_dset=val_dset, test_dset=test_dset,
#         train_loader=train_loader, val_loader=val_loader, test_loader=test_loader,
#     ), class_names)


# def get_dset_intel_mobileodt(stage_trainval:str, use_val:str, stage_test:str, augment:str
#                              ) -> (dict[str,Optional[Union[Dataset,DataLoader]]], tuple[str]):
#     """Obtain train/val/test splits for the IntelMobileODT Cervical Cancer
#     Colposcopy dataset, and the data loaders.

#     Args:
#         stage_trainval: the `stage` for training and validation.
#             i.e. Possible choices:  {'train', 'train+additional'}
#             Train / val split is 70/30 random stratified split.
#         use_val: Whether to create a validation set
#             Choices:  {"val", "noval"}
#         stage_test: the `stage` for test set.  Should be "test".
#         augment: Type of augmentations to apply.  One of {'v1', }.
#             "v1" - make the aspect ratio .75, resize images to (200,150), and convert in range [0,1]
#     Returns:
#         (
#         {'train_dset': ..., 'val_dset': ..., 'test_dset': ...,
#          'train_loader': ..., 'val_loader': ..., 'test_loader': ...
#          },

#         ('Type 1', 'Type 2', 'Type 3')
#         )
#     """
#     assert augment == 'v1', 'code bug: other augmentations not implemented'
#     base_dir = './data/intel_mobileodt_cervical_resized'
#     dset_trainval = D.IntelMobileODTCervical(stage_trainval, base_dir)
#     _y = [dset_trainval.getitem(i, load_img=False)
#           for i in range(len(dset_trainval))]
#     dct = {'test_dset': D.IntelMobileODTCervical(stage_test, base_dir)}
#     if use_val == 'noval':
#         dct['train_dset'] = dset_trainval
#         dct['val_dset'] = None
#     else:
#         assert use_val == 'val', f'unrecognized option: {use_val}'
#         idxs_train, idxs_val = list(
#             StratifiedShuffleSplit(1, test_size=.3).split(
#                 np.arange(len(dset_trainval)), _y))[0]
#         dct['train_dset'] = T.utils.data.Subset(dset_trainval, idxs_train)
#         dct['val_dset'] = T.utils.data.Subset(dset_trainval, idxs_val)

#     # preprocess train/val/test images all the same way
#     preprocess_v1 = tvt.Compose([
#         #
#         ### previously done (to save computation time) ###
#         #  D.IntelMobileODTCervical.fix_aspect_ratio,
#         #  tvt.Resize((200, 150)),  # interpolation=tvt.InterpolationMode.NEAREST),
#         #
#         lambda x: x.float()/255.
#     ])
#     dct = {k: D.PreProcess(v, lambda xy: (
#         preprocess_v1(xy[0]),
#         #  onehot(xy[1].unsqueeze(0).long()-1, 3).squeeze_().float()))
#         xy[1].long()-1))
#         for k,v in dct.items()}
#     dct.update(dict(
#         train_loader=DataLoader(dct['train_dset'], batch_size=20, shuffle=True),
#         test_loader=DataLoader(dct['test_dset'], batch_size=20),))
#     if dct['val_dset'] is None:
#         dct['val_loader'] = None
#     else:
#         dct['val_loader'] = DataLoader(dct['val_dset'], batch_size=20)
#     class_names = [x.replace('_', ' ') for x in D.IntelMobileODTCervical.LABEL_NAMES]
#     return dct, class_names


# LOSS_FNS = {
#     ('BCEWithLogitsLoss', ): lambda _: T.nn.BCEWithLogitsLoss(),
#     ('CrossEntropyLoss', ): lambda _: T.nn.CrossEntropyLoss(),
#     ('CE_intelmobileodt', ): lambda _: loss_intelmobileodt,
#     ('chexpert_uignore', ): lambda _: LossCheXpertUignore(),
#     ('chexpert_identity', str): lambda out_ch: LossCheXpertIdentity(N=int(out_ch)),
# }

# DSETS = {
#     ('intel_mobileodt', str, str, str, str): (
#         lambda train, val, test, aug: get_dset_intel_mobileodt(train, val, test, aug)),
#     #  ('origa', ... todo): ( lambda ...: get_dset_origa(...)
#     #  ('riga', ... todo): ( lambda ...: get_dset_riga(...)
#     ('chexpert', str, str): (
#         lambda train_frac, val_frac: get_dset_chexpert(
#             float(train_frac), float(val_frac), small=False, labels='diagnostic')),
#     ('chexpert_small', str, str): (
#         lambda train_frac, val_frac: get_dset_chexpert(
#             float(train_frac), float(val_frac), small=True, labels='diagnostic')),
#     ('chexpert_small_ID', str, str, str): (
#         lambda num_identities, train_frac, val_frac: get_dset_chexpert(
#             float(train_frac), float(val_frac), small=True,
#             labels='identity', num_identities=int(num_identities))),
# }


# def match(spec:str, dct:dict):
#     return pampy.match(spec.split(':'), *(x for y in dct.items() for x in y))


# def get_model_opt_loss(
#         model_spec:str, opt_spec:str, loss_spec:str, regularizer_spec:str,
#         device:str) -> dict[str, Union[T.nn.Module, T.optim.Optimizer]]:
#     """
#     Args:
#         model_spec: a string of form,
#             "model_name:pretraining:in_channels:out_classes".  For example:
#             "effnetv2:untrained:1:5"
#         opt_spec: Specifies how to create optimizer.
#             First value is a pytorch Optimizer in T.optim.*.
#             Other values are numerical parameters.
#             Example: "SGD:lr=.003:momentum=.9"
#         device: e.g. 'cpu' or 'gpu'
#     Returns:
#         a pytorch model and optimizer
#     """
#     mdl = match(model_spec, MODELS)
#     mdl = mdl.to(device, non_blocking=True)
#     optimizer = reset_optimizer(opt_spec, mdl)
#     loss_fn = match(loss_spec, LOSS_FNS)
#     if regularizer_spec != 'none':
#         loss_fn = RegularizedLoss(mdl, loss_fn, regularizer_spec)
#     return dict(model=mdl, optimizer=optimizer, loss_fn=loss_fn)


# class RegularizedLoss(T.nn.Module):
#     def __init__(self, model, lossfn, regularizer_spec:str):
#         super().__init__()
#         self.lossfn = lossfn
#         self.regularizer_spec = regularizer_spec
#         if regularizer_spec == 'none':
#             self.regularizer = lambda *y: 0
#         elif regularizer_spec.startswith('deepfixmlp:'):
#             lbda = float(regularizer_spec.split(':')[1])
#             self.regularizer = lambda *y: (
#                 float(lbda) * DeepFixMLP.get_VecAttn_regularizer(model))
#         else:
#             raise NotImplementedError(regularizer_spec)

#     def forward(self, yhat, y):
#         return self.lossfn(yhat, y) + self.regularizer(yhat, y)

#     def __repr__(self):
#         return f'RegularizedLoss<{repr(self.lossfn)},{self.regularizer_spec}>'


# def get_dset_loaders_resultfactory(dset_spec:str) -> dict:
#     dct, class_names = match(dset_spec, DSETS)
#     if any(dset_spec.startswith(x) for x in {'intel_mobileodt:',
#                                              'chexpert_small_ID:'}):
#         #  dct['result_factory'] = lambda: TL.MultiLabelBinaryClassification(
#                 #  class_names, binarize_fn=lambda yh: (T.sigmoid(yh)>.5).long())
#         dct['result_factory'] = lambda: TL.MultiClassClassification(
#                 len(class_names), binarize_fn=lambda yh: yh.softmax(1).argmax(1))
#     elif any(dset_spec.startswith(x) for x in {'chexpert:', 'chexpert_small:'}):
#         dct['result_factory'] = lambda: CheXpertMultiLabelBinaryClassification(
#             class_names, binarize_fn=lambda yh: (yh.sigmoid()>.5).long(), report_avg=True)
#     else:
#         raise NotImplementedError(f"I don't know how to create the result factory for {dset_spec}")
#     return dct

# class CheXpertMultiLabelBinaryClassification(TL.MultiLabelBinaryClassification):
#     def update(self, yhat, y, loss) -> None:
#         self.num_samples += yhat.shape[0]
#         self.loss += loss.item()
#         assert yhat.shape == y.shape
#         assert yhat.ndim == 2 and yhat.shape[1] == len(self._cms), "sanity check: model outputs expected prediction shape"
#         binarized = self._binarize_fn(yhat)
#         assert binarized.dtype == T.long, 'sanity check binarize fn'
#         assert binarized.shape == y.shape, 'sanity check binarize fn'
#         ignore = (y != 2)  # ignore uncertainty labels
#         for i, (kls, cm) in enumerate(self._cms.items()):
#             rows = ignore[:, i]
#             if rows.sum() == 0:
#                 continue  # don't update a confusion matrix if all data for this class is ignored
#             cm += metrics.confusion_matrix(y[rows, i], binarized[rows, i], num_classes=2).cpu()


# def get_deepfix_train_strategy(args:'TrainOptions'):
#     deepfix_spec = args.deepfix
#     if deepfix_spec == 'off':
#         return TL.train_one_epoch
#     elif deepfix_spec.startswith('reinit:'):
#         _, N, P, R = deepfix_spec.split(':')
#         return dfs.DeepFix_TrainOneEpoch(int(N), float(P), int(R), TL.train_one_epoch)
#     elif deepfix_spec.startswith('dhist:'):
#         fp = deepfix_spec.split(':', 1)[1]
#         assert exists(fp), f'histogram file not found: {fp}'
#         return dfs.DeepFix_DHist(fp)
#     elif deepfix_spec.startswith('dfhist:'):
#         fp = deepfix_spec.split(':', 1)[1]
#         assert exists(fp), f'histogram file not found: {fp}'
#         return dfs.DeepFix_DHist(fp, fixed=True)
#     elif deepfix_spec == 'fixed':
#         return dfs.DeepFix_DHist('', fixed=True, init_with_hist=False)
#     elif deepfix_spec.startswith('beta:'):
#         alpha, beta = deepfix_spec.split(':')[1:]
#         return dfs.DeepFix_LambdaInit(
#             lambda cfg: init_from_beta(cfg.model, float(alpha), float(beta)))
#     elif deepfix_spec.startswith('ghaarconv2d:'):
#         ignore_layers = deepfix_spec.split(':')[1].split(',')
#         return dfs.DeepFix_LambdaInit(
#             lambda cfg: (
#                 print(f'initialize {deepfix_spec}'),
#                 convert_conv2d_to_gHaarConv2d(cfg.model, ignore_layers=ignore_layers),
#                 reset_optimizer(args.opt, cfg.model),
#                 print(cfg.model)
#             ))
#     else:
#         raise NotImplementedError(deepfix_spec)


# def train_config(args:'TrainOptions') -> TL.TrainConfig:
#     return TL.TrainConfig(
#         **get_model_opt_loss(
#             args.model, args.opt, args.lossfn, args.loss_reg, args.device),
#         **get_dset_loaders_resultfactory(args.dset),
#         device=args.device,
#         epochs=args.epochs,
#         start_epoch=args.start_epoch,
#         train_one_epoch=get_deepfix_train_strategy(args),
#         experiment_id=args.experiment_id,
#     )


# @dc.dataclass
# class TrainOptions:
#     """High-level configuration for training PyTorch models
#     on the IntelMobileODTCervical dataset.
#     """
#     epochs:int = 50
#     start_epoch:int = 0  # if "--start_epoch 1", then don't evaluate perf before training.
#     device:str = 'cuda' if T.cuda.is_available() else 'cpu'
#     dset:str = None #choice(
#         #  'intel_mobileodt:train:val:test:v1',
#         #  'intel_mobileodt:train+additional:val:test:v1',
#         #  'intel_mobileodt:train+additional:noval:test:v1',
#         #  'chexpert:.8:.2', 'chexpert:.01:.01', 'chexpert:.001:.001',
#         #  'chexpert_small:.8:.2', 'chexpert_small:.01:.01',
#         #   'chexpert_small:.001:.001',
#         #  default='intel_mobileodt:train:val:test:v1')
#     opt:str = 'SGD:lr=.001:momentum=.9:nesterov=1'
#     lossfn:str = None  # choices:
#         #  'BCEWithLogitsLoss',
#         #  'CrossEntropyLoss', 
#         #  'CE_intelmobileodt',
#         #  'chexpert_uignore', 
#         #  'chexpert_identity:N' for some N=num_identities predicted by model (compared to identities y%N)
#     loss_reg:str = 'none'  # Optionally add a regularizer to the loss.  loss + reg.  Accepted values:  'none', 'deepfixmlp:X' where X is a positive float denoting the lambda in l1 regularizer
#     model:str = 'resnet18:imagenet:3:3'  # Model specification adheres to the template "model_name:pretraining:in_ch:out_ch"
#     deepfix:str = 'off'  # DeepFix Re-initialization Method.
#                          #  "off" or "reinit:N:P:R" or "d[f]hist:path_to_histogram.pth"
#                          #  or "beta:A:B" for A,B as (float) parameters of the beta distribution
#                          # 'ghaarconv2d:layer1,layer2' Replaces all spatial convolutions with GHaarConv2d layer except the specified layers
#     experiment_id:str = os.environ.get('run_id', 'debugging')
#     prune:str = 'off'

#     def execute(self):
#         cfg = train_config(self)
#         cfg.train(cfg)


# def main():
#     p = ArgumentParser()
#     p.add_arguments(TrainOptions, dest='TrainOptions')

# #     args = p.parse_args(["--dset", "chexpert_small:.01:.01", "--opt", "Adam:lr=0.001", "--lossfn", "chexpert_uignore", "--model", "waveletmlp:300:1:14:7:1:1:2", "--loss_reg", "none"]).TrainOptions

#     print(args)
#     cfg = train_config(args)
    
# # python deepfix/train.py --dset chexpert_small:.01:.01 --opt Adam:lr=0.001 --lossfn chexpert_uignore --model waveletmlp:300:1:14:7:1:1:2 --loss_reg none    
    
#     if args.prune != 'off':
#         assert args.prune.startswith('ChannelPrune:')
#         raise NotImplementedError('code is a bit hardcoded, so it is not available without hacking on it.')
#         print(args.prune)
#         from explainfix import channelprune
#         from deepfix.weight_saliency import costfn_multiclass
#         a = sum([x.numel() for x in cfg.model.parameters()])
#         channelprune(cfg.model, pct=5, grad_cost_fn=costfn_multiclass,
#                      loader=cfg.train_loader, device=cfg.device, num_minibatches=10)
#         b = sum([x.numel() for x in cfg.model.parameters()])
#         assert a/b != 1
#         print(f'done channelpruning.  {a/b}')

#     cfg.train(cfg)
#     #  import IPython ; IPython.embed() ; import sys ; sys.exit()

#     #  with T.profiler.profile(
#     #      activities=[
#     #          T.profiler.ProfilerActivity.CPU,
#     #          T.profiler.ProfilerActivity.CUDA,
#     #      ], with_modules=True,
#     #  ) as p:
#     #      cfg.train(cfg)
#     #  print(p.key_averages().table(
#     #      sort_by="self_cuda_time_total", row_limit=-1))


# if __name__ == "__main__":
#     main()

# %%
# os.getcwd()
# !ls

# %%
# args = {}
# args['dset'] = 'chexpert_small:.01:.01'
# args['opt'] = 'Adam:lr=0.001'
# args['lossfn'] = 'chexpert_uignore'
# args['model'] = 'waveletmlp:300:1:14:7:1:1:2'
# args['loss_reg'] = None
# args['prune'] = 'off'

# %%
# args.dset

# %%
# import pandas as pd

# %%
# t = pd.read_csv('../data/CheXpert-v1.0-small/train.csv')
