# %%
"""
Boilerplate to implement training different networks on different datasets
with varying config.

I wish a machine could automate setting up decent baseline models and datasets
"""
#  import json
import os
from os.path import exists
import pampy
from simple_parsing import ArgumentParser, choice
from simplepytorch import datasets as D
from simplepytorch import trainlib as TL
from simplepytorch import metrics
from sklearn.model_selection import StratifiedShuffleSplit
from torch.utils.data import Dataset, DataLoader
from typing import Union, Optional
import dataclasses as dc
import numpy as np
import torch as T
import torchvision.transforms as tvt

from deepfix.models import get_effnetv2, get_resnet, get_efficientnetv1, get_DeepFixEnd2End, DeepFixMLP
from deepfix.models.ghaarconv import convert_conv2d_to_gHaarConv2d
from deepfix.init_from_distribution import init_from_beta, reset_optimizer
from deepfix import deepfix_strategies as dfs
import pytorch_wavelets as pyw
# Out:
# WARNING:root:QualDR dataset labels unavailable because pyjq not installed

# %%
MODELS = {
    ('effnetv2', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_effnetv2(pretrain, int(in_ch), int(out_ch))),
    ('resnet50', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_resnet('resnet50', pretrain, int(in_ch), int(out_ch))),
    ('resnet18', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_resnet('resnet18', pretrain, int(in_ch), int(out_ch))),
    ('efficientnet-b0', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_efficientnetv1('efficientnet-b0', pretrain, int(in_ch), int(out_ch))),
    ('efficientnet-b1', str, str, str): (
        lambda pretrain, in_ch, out_ch: get_efficientnetv1('efficientnet-b1', pretrain, int(in_ch), int(out_ch))),
    ('waveletres18', str, str, str): lambda pretrain, in_ch, out_ch: R(
        pretrain, int(in_ch), int(out_ch)),
    ('waveletmlp', str, str, str, str, str, str, str): (
        lambda mlp_channels, in_ch, out_ch, wavelet_levels, patch_size, in_ch_mul, mlp_depth: get_DeepFixEnd2End(
            int(in_ch), int(out_ch),
            in_ch_multiplier=int(in_ch_mul), wavelet='db1',
            wavelet_levels=int(wavelet_levels), wavelet_patch_size=int(patch_size),
            mlp_depth=int(mlp_depth), mlp_channels=int(mlp_channels),
            mlp_fix_weights='none', mlp_activation=None)
        ),

    #  ('waveletres18v2', str, str, str): lambda pretrain, in_ch, out_ch: (
        #  DeepFixCompression(levels=8, wavelet='coif1', patch_size=1),
        #  R2(pretrain, int(in_ch), int(out_ch))),
}


class R(T.nn.Module):
    def __init__(self, pretrain, in_ch, out_ch):
        super().__init__()
        self.r = get_resnet('resnet18', pretrain, in_ch, out_ch,)
        self.dwt = pyw.DWT(J=8, wave='coif1', mode='zero')

    @staticmethod
    def wavelet_coefficients_as_tensorimage(approx, detail, normalize=False):
        B,C = approx.shape[:2]
        fixed_dims = approx.shape[:-2] # num images in minibatch, num channels, etc
        output_shape = fixed_dims + (
            detail[0].shape[-2]*2,  # input img height
            detail[0].shape[-1]*2)  # input img width
        im = T.zeros(output_shape, device=approx.device, dtype=approx.dtype)
        if normalize:
            norm11 = lambda x: (x / max(x.min()*-1, x.max()))  # into [-1,+1] preserving sign
            #  approx = norm11(approx)
        im[..., :approx.shape[-2], :approx.shape[-1]] = approx if approx is not None else 0
        for level in detail:
            lh, hl, hh = level.unbind(-3)
            h,w = lh.shape[-2:]
            if normalize:
                lh, hl, hh = [norm11(x) for x in [lh, hl, hh]]
            #  im[:h, :w] = approx
            im[..., 0:h, w:w+w] = lh  # horizontal
            im[..., h:h+h, :w] = hl  # vertical
            im[..., h:h+h, w:w+w] = hh  # diagonal
        return im

    def forward(self, x):
        x = self.wavelet_coefficients_as_tensorimage(*self.dwt(x))
        return self.r(x)


class R2(T.nn.Module):
    def __init__(self, pretrain, in_ch, out_ch):
        super().__init__()
        self.r = get_resnet('resnet18', pretrain, in_ch, out_ch,)

    def forward(self, x):
        B,C,H = x.shape
        x = x.unsqueeze(-1).repeat(1,1,1,H)
        return self.r(x)


class LossCheXpertIdentity(T.nn.Module):
    def __init__(self, N):
        super().__init__()
        self.bce = T.nn.BCEWithLogitsLoss()
        self.N = N

    def forward(self, yhat, y):
        # absolute max possible num patients in chexpert is 223414
        # but let's just hash them into a smaller number of bins via modulo N
        assert self.N == yhat.shape[1], \
                f'note: model must have {self.N} binary predictions per sample'
        y_onehot = y.new_zeros(y.shape[0], self.N, dtype=T.float
                               ).scatter_(1, y.long()%self.N, 1)
        return self.bce(yhat[:, -1], y_onehot[:, -1])


class LossCheXpertUignore(T.nn.Module):
    def __init__(self):
        super().__init__()
        self.bce = T.nn.BCEWithLogitsLoss()

    def forward(self, yhat, y):
        ignore = (y != 2)  # ignore uncertainty labels
        return self.bce(yhat[ignore], y[ignore])


def loss_intelmobileodt(yhat, y):
    """BCE Loss with class balancing weights.

    Not sure this actually helps

    because Type 2 is the hardest class, it
    has the most samples, and it separates Type 1 from Type 3.  Arguably, Type 2
    samples are on the decision boundary between Type 1 and 3.
    Class balancing weights make it harder to focus on class 2.
    """
    #  assert y.shape == yhat.shape, 'sanity check'
    #  assert y.dtype == yhat.dtype, 'sanity check'

    # class distribution of stage='train'
    w = T.tensor([249, 781, 450], dtype=y.dtype, device=y.device)
    w = (w.max() / w).reshape(1, 3)
    # w can have any of the shapes:  (B,1) or (1,C) or (B,C)
    #  return T.nn.functional.binary_cross_entropy_with_logits(yhat, y, weight=w)
    return T.nn.functional.cross_entropy(yhat, y, weight=w)
    # can't apply focal loss unless do it manually.


def onehot(y, nclasses):
    return T.zeros((y.numel(), nclasses), dtype=y.dtype, device=y.device)\
            .scatter_(1, y.unsqueeze(1), 1)


def _upsample_pad_minibatch_imgs_to_same_size(batch, target_is_segmentation_mask=False):
    """a collate function for a dataloader of (x,y) samples.  """
    shapes = [item[0].shape for item in batch]
    H = max(h for c,h,w in shapes)
    W = max(w for c,h,w in shapes)
    X, Y = [], []
    for item in batch:
        h,w = item[0].shape[1:]
        dh, dw = (H-h), (W-w)
        padding = (dw//2, dw-dw//2, dh//2, dh-dh//2, )
        X.append(T.nn.functional.pad(item[0], padding))
        if target_is_segmentation_mask:
            Y.append(T.nn.functional.pad(item[1], padding))
        else:
            Y.append(item[1])
    return T.stack(X), T.stack(Y)


def get_dset_chexpert(train_frac=.8, val_frac=.2, small=False,
                      labels:str='diagnostic', num_identities=None):
    """
    Args:
        labels:  either "diagnostic" (the 14 classes defined as
            D.CheXpert.LABELS_DIAGNOSTIC) or "identity" ("patient", "study",
            "view", "index")
        small:  whether to use CheXpert_Small dataset (previously downsampled
            images) or the fully size dataset.
        num_identities:  used only if labels='identity'.  If
            num_identities=1000, then all patients get identified as coming
            from precisely 1 of 1000 bins.

    Returns:
        (
        {'train_dset': ..., 'val_dset': ..., 'test_dset': ...,
         'train_loader': ..., 'val_loader': ..., 'test_loader': ...
         },

        ('Pneumonia', 'Cardiomegaly', ...)  # class names defined by `labels`
        )
    """
    _label_cleanup_dct = dict(D.CheXpert.LABEL_CLEANUP_DICT)
    if labels == 'diagnostic':
        class_names = D.CheXpert.LABELS_DIAGNOSTIC
        for k in class_names:
            _label_cleanup_dct[k][np.nan] = 0  # remap missing value to negative
        get_ylabels = lambda dct: \
                D.CheXpert.format_labels(dct, labels=class_names).float()
    elif labels == 'identity':
        class_names = list(range(num_identities))
        get_ylabels = lambda dct: \
                (D.CheXpert.format_labels(dct, labels=['index']) % num_identities).long()
    else:
        raise NotImplementedError(f"unrecognized labels: {labels}")
    kws = dict(
        img_transform=tvt.Compose([
#              tvt.RandomCrop((512, 512)),
            tvt.ToTensor(),  # full res 1024x1024 imgs
        ]),
        getitem_transform=lambda dct: (dct['image'], get_ylabels(dct)),
        label_cleanup_dct=_label_cleanup_dct,
    )
    if small:
        kls = D.CheXpert_Small
    else:
        kls = D.CheXpert

    train_dset = kls(dataset_dir="../data/CheXpert-v1.0-small/",use_train_set=True, **kws)  #Edited Elvin

    N = len(train_dset)
    if train_frac + val_frac == 1:
        nsplits = [N - int(N*val_frac), int(N*val_frac), 0]
    else:
        a,b = int(N*train_frac), int(N*val_frac)
        nsplits = [a,b, N-a-b]
    train_dset, val_dset, _ = T.utils.data.random_split(train_dset, nsplits)
    test_dset = kls(dataset_dir="../data/CheXpert-v1.0-small/",use_train_set=False, **kws) #Edited Elvin
    batch_dct = dict(
        batch_size=15, collate_fn=_upsample_pad_minibatch_imgs_to_same_size,
        num_workers=int(os.environ.get("num_workers", 4)))  # upsample pad must take time
    train_loader=DataLoader(train_dset, shuffle=True, **batch_dct)
    val_loader=DataLoader(val_dset, **batch_dct)
    test_loader=DataLoader(test_dset, **batch_dct)
    return (dict(
        train_dset=train_dset, val_dset=val_dset, test_dset=test_dset,
        train_loader=train_loader, val_loader=val_loader, test_loader=test_loader,
    ), class_names)


def get_dset_intel_mobileodt(stage_trainval:str, use_val:str, stage_test:str, augment:str
                             ) -> (dict[str,Optional[Union[Dataset,DataLoader]]], tuple[str]):
    """Obtain train/val/test splits for the IntelMobileODT Cervical Cancer
    Colposcopy dataset, and the data loaders.

    Args:
        stage_trainval: the `stage` for training and validation.
            i.e. Possible choices:  {'train', 'train+additional'}
            Train / val split is 70/30 random stratified split.
        use_val: Whether to create a validation set
            Choices:  {"val", "noval"}
        stage_test: the `stage` for test set.  Should be "test".
        augment: Type of augmentations to apply.  One of {'v1', }.
            "v1" - make the aspect ratio .75, resize images to (200,150), and convert in range [0,1]
    Returns:
        (
        {'train_dset': ..., 'val_dset': ..., 'test_dset': ...,
         'train_loader': ..., 'val_loader': ..., 'test_loader': ...
         },

        ('Type 1', 'Type 2', 'Type 3')
        )
    """
    assert augment == 'v1', 'code bug: other augmentations not implemented'
    base_dir = './data/intel_mobileodt_cervical_resized'
    dset_trainval = D.IntelMobileODTCervical(stage_trainval, base_dir)
    _y = [dset_trainval.getitem(i, load_img=False)
          for i in range(len(dset_trainval))]
    dct = {'test_dset': D.IntelMobileODTCervical(stage_test, base_dir)}
    if use_val == 'noval':
        dct['train_dset'] = dset_trainval
        dct['val_dset'] = None
    else:
        assert use_val == 'val', f'unrecognized option: {use_val}'
        idxs_train, idxs_val = list(
            StratifiedShuffleSplit(1, test_size=.3).split(
                np.arange(len(dset_trainval)), _y))[0]
        dct['train_dset'] = T.utils.data.Subset(dset_trainval, idxs_train)
        dct['val_dset'] = T.utils.data.Subset(dset_trainval, idxs_val)

    # preprocess train/val/test images all the same way
    preprocess_v1 = tvt.Compose([
        #
        ### previously done (to save computation time) ###
        #  D.IntelMobileODTCervical.fix_aspect_ratio,
        #  tvt.Resize((200, 150)),  # interpolation=tvt.InterpolationMode.NEAREST),
        #
        lambda x: x.float()/255.
    ])
    dct = {k: D.PreProcess(v, lambda xy: (
        preprocess_v1(xy[0]),
        #  onehot(xy[1].unsqueeze(0).long()-1, 3).squeeze_().float()))
        xy[1].long()-1))
        for k,v in dct.items()}
    dct.update(dict(
        train_loader=DataLoader(dct['train_dset'], batch_size=20, shuffle=True),
        test_loader=DataLoader(dct['test_dset'], batch_size=20),))
    if dct['val_dset'] is None:
        dct['val_loader'] = None
    else:
        dct['val_loader'] = DataLoader(dct['val_dset'], batch_size=20)
    class_names = [x.replace('_', ' ') for x in D.IntelMobileODTCervical.LABEL_NAMES]
    return dct, class_names


LOSS_FNS = {
    ('BCEWithLogitsLoss', ): lambda _: T.nn.BCEWithLogitsLoss(),
    ('CrossEntropyLoss', ): lambda _: T.nn.CrossEntropyLoss(),
    ('CE_intelmobileodt', ): lambda _: loss_intelmobileodt,
    ('chexpert_uignore', ): lambda _: LossCheXpertUignore(),
    ('chexpert_identity', str): lambda out_ch: LossCheXpertIdentity(N=int(out_ch)),
}

DSETS = {
    ('intel_mobileodt', str, str, str, str): (
        lambda train, val, test, aug: get_dset_intel_mobileodt(train, val, test, aug)),
    #  ('origa', ... todo): ( lambda ...: get_dset_origa(...)
    #  ('riga', ... todo): ( lambda ...: get_dset_riga(...)
    ('chexpert', str, str): (
        lambda train_frac, val_frac: get_dset_chexpert(
            float(train_frac), float(val_frac), small=False, labels='diagnostic')),
    ('chexpert_small', str, str): (
        lambda train_frac, val_frac: get_dset_chexpert(
            float(train_frac), float(val_frac), small=True, labels='diagnostic')),
    ('chexpert_small_ID', str, str, str): (
        lambda num_identities, train_frac, val_frac: get_dset_chexpert(
            float(train_frac), float(val_frac), small=True,
            labels='identity', num_identities=int(num_identities))),
}


def match(spec:str, dct:dict):
    return pampy.match(spec.split(':'), *(x for y in dct.items() for x in y))


def get_model_opt_loss(
        model_spec:str, opt_spec:str, loss_spec:str, regularizer_spec:str,
        device:str) -> dict[str, Union[T.nn.Module, T.optim.Optimizer]]:
    """
    Args:
        model_spec: a string of form,
            "model_name:pretraining:in_channels:out_classes".  For example:
            "effnetv2:untrained:1:5"
        opt_spec: Specifies how to create optimizer.
            First value is a pytorch Optimizer in T.optim.*.
            Other values are numerical parameters.
            Example: "SGD:lr=.003:momentum=.9"
        device: e.g. 'cpu' or 'gpu'
    Returns:
        a pytorch model and optimizer
    """
    mdl = match(model_spec, MODELS)
    mdl = mdl.to(device, non_blocking=True)
    optimizer = reset_optimizer(opt_spec, mdl)
    loss_fn = match(loss_spec, LOSS_FNS)
    if regularizer_spec != 'none':
        loss_fn = RegularizedLoss(mdl, loss_fn, regularizer_spec)
    return dict(model=mdl, optimizer=optimizer, loss_fn=loss_fn)


class RegularizedLoss(T.nn.Module):
    def __init__(self, model, lossfn, regularizer_spec:str):
        super().__init__()
        self.lossfn = lossfn
        self.regularizer_spec = regularizer_spec
        if regularizer_spec == 'none':
            self.regularizer = lambda *y: 0
        elif regularizer_spec.startswith('deepfixmlp:'):
            lbda = float(regularizer_spec.split(':')[1])
            self.regularizer = lambda *y: (
                float(lbda) * DeepFixMLP.get_VecAttn_regularizer(model))
        else:
            raise NotImplementedError(regularizer_spec)

    def forward(self, yhat, y):
        return self.lossfn(yhat, y) + self.regularizer(yhat, y)

    def __repr__(self):
        return f'RegularizedLoss<{repr(self.lossfn)},{self.regularizer_spec}>'


def get_dset_loaders_resultfactory(dset_spec:str) -> dict:
    dct, class_names = match(dset_spec, DSETS)
    if any(dset_spec.startswith(x) for x in {'intel_mobileodt:',
                                             'chexpert_small_ID:'}):
        #  dct['result_factory'] = lambda: TL.MultiLabelBinaryClassification(
                #  class_names, binarize_fn=lambda yh: (T.sigmoid(yh)>.5).long())
        dct['result_factory'] = lambda: TL.MultiClassClassification(
                len(class_names), binarize_fn=lambda yh: yh.softmax(1).argmax(1))
    elif any(dset_spec.startswith(x) for x in {'chexpert:', 'chexpert_small:'}):
        dct['result_factory'] = lambda: CheXpertMultiLabelBinaryClassification(
            class_names, binarize_fn=lambda yh: (yh.sigmoid()>.5).long(), report_avg=True)
    else:
        raise NotImplementedError(f"I don't know how to create the result factory for {dset_spec}")
    return dct

class CheXpertMultiLabelBinaryClassification(TL.MultiLabelBinaryClassification):
    def update(self, yhat, y, loss) -> None:
        self.num_samples += yhat.shape[0]
        self.loss += loss.item()
        assert yhat.shape == y.shape
        assert yhat.ndim == 2 and yhat.shape[1] == len(self._cms), "sanity check: model outputs expected prediction shape"
        binarized = self._binarize_fn(yhat)
        assert binarized.dtype == T.long, 'sanity check binarize fn'
        assert binarized.shape == y.shape, 'sanity check binarize fn'
        ignore = (y != 2)  # ignore uncertainty labels
        for i, (kls, cm) in enumerate(self._cms.items()):
            rows = ignore[:, i]
            if rows.sum() == 0:
                continue  # don't update a confusion matrix if all data for this class is ignored
            cm += metrics.confusion_matrix(y[rows, i], binarized[rows, i], num_classes=2).cpu()


def get_deepfix_train_strategy(args:'TrainOptions'):
    deepfix_spec = args.deepfix
    if deepfix_spec == 'off':
        return TL.train_one_epoch
    elif deepfix_spec.startswith('reinit:'):
        _, N, P, R = deepfix_spec.split(':')
        return dfs.DeepFix_TrainOneEpoch(int(N), float(P), int(R), TL.train_one_epoch)
    elif deepfix_spec.startswith('dhist:'):
        fp = deepfix_spec.split(':', 1)[1]
        assert exists(fp), f'histogram file not found: {fp}'
        return dfs.DeepFix_DHist(fp)
    elif deepfix_spec.startswith('dfhist:'):
        fp = deepfix_spec.split(':', 1)[1]
        assert exists(fp), f'histogram file not found: {fp}'
        return dfs.DeepFix_DHist(fp, fixed=True)
    elif deepfix_spec == 'fixed':
        return dfs.DeepFix_DHist('', fixed=True, init_with_hist=False)
    elif deepfix_spec.startswith('beta:'):
        alpha, beta = deepfix_spec.split(':')[1:]
        return dfs.DeepFix_LambdaInit(
            lambda cfg: init_from_beta(cfg.model, float(alpha), float(beta)))
    elif deepfix_spec.startswith('ghaarconv2d:'):
        ignore_layers = deepfix_spec.split(':')[1].split(',')
        return dfs.DeepFix_LambdaInit(
            lambda cfg: (
                print(f'initialize {deepfix_spec}'),
                convert_conv2d_to_gHaarConv2d(cfg.model, ignore_layers=ignore_layers),
                reset_optimizer(args.opt, cfg.model),
                print(cfg.model)
            ))
    else:
        raise NotImplementedError(deepfix_spec)


def train_config(args:'TrainOptions') -> TL.TrainConfig:
    return TL.TrainConfig(
        **get_model_opt_loss(
            args.model, args.opt, args.lossfn, args.loss_reg, args.device),
        **get_dset_loaders_resultfactory(args.dset),
        device=args.device,
        epochs=args.epochs,
        start_epoch=args.start_epoch,
        train_one_epoch=get_deepfix_train_strategy(args),
        experiment_id=args.experiment_id,
    )


@dc.dataclass
class TrainOptions:
    """High-level configuration for training PyTorch models
    on the IntelMobileODTCervical dataset.
    """
    epochs:int = 50
    start_epoch:int = 0  # if "--start_epoch 1", then don't evaluate perf before training.
    device:str = 'cuda' if T.cuda.is_available() else 'cpu'
    dset:str = None #choice(
        #  'intel_mobileodt:train:val:test:v1',
        #  'intel_mobileodt:train+additional:val:test:v1',
        #  'intel_mobileodt:train+additional:noval:test:v1',
        #  'chexpert:.8:.2', 'chexpert:.01:.01', 'chexpert:.001:.001',
        #  'chexpert_small:.8:.2', 'chexpert_small:.01:.01',
        #   'chexpert_small:.001:.001',
        #  default='intel_mobileodt:train:val:test:v1')
    opt:str = 'SGD:lr=.001:momentum=.9:nesterov=1'
    lossfn:str = None  # choices:
        #  'BCEWithLogitsLoss',
        #  'CrossEntropyLoss', 
        #  'CE_intelmobileodt',
        #  'chexpert_uignore', 
        #  'chexpert_identity:N' for some N=num_identities predicted by model (compared to identities y%N)
    loss_reg:str = 'none'  # Optionally add a regularizer to the loss.  loss + reg.  Accepted values:  'none', 'deepfixmlp:X' where X is a positive float denoting the lambda in l1 regularizer
    model:str = 'resnet18:imagenet:3:3'  # Model specification adheres to the template "model_name:pretraining:in_ch:out_ch"
    deepfix:str = 'off'  # DeepFix Re-initialization Method.
                         #  "off" or "reinit:N:P:R" or "d[f]hist:path_to_histogram.pth"
                         #  or "beta:A:B" for A,B as (float) parameters of the beta distribution
                         # 'ghaarconv2d:layer1,layer2' Replaces all spatial convolutions with GHaarConv2d layer except the specified layers
    experiment_id:str = os.environ.get('run_id', 'debugging')
    prune:str = 'off'

    def execute(self):
        cfg = train_config(self)
        cfg.train(cfg)


def main():
    p = ArgumentParser()
    p.add_arguments(TrainOptions, dest='TrainOptions')
#     for patch_size in [1,32]:
#         for wavelet_level in [1,2,3,4,5,6,7,8,9]:    
#             try:
    in_ch, out_ch = 1, 14
    model_params = "waveletres18:imagenet:"+str(in_ch)+":"+str(out_ch)    
    
#     model_params = "waveletmlp:300:1:14:"+str(patch_size)+":"+str(wavelet_level)+":1:2"
    exp_id = 'model_'+model_params+'_in_ch_'+str(in_ch)+'out_ch_'+str(out_ch)#+'_patch_size_' + str(patch_size) + '_level_' + str(wavelet_level)
    args = p.parse_args(["--dset", "chexpert_small:.01:.01", "--opt", "Adam:lr=0.001", "--lossfn", "chexpert_uignore", "--model", model_params, "--loss_reg", "none","--experiment_id",exp_id]).TrainOptions

    print(args)
    cfg = train_config(args)

# python deepfix/train.py --dset chexpert_small:.01:.01 --opt Adam:lr=0.001 --lossfn chexpert_uignore --model waveletmlp:300:1:14:7:1:1:2 --loss_reg none    

    if args.prune != 'off':
        assert args.prune.startswith('ChannelPrune:')
        raise NotImplementedError('code is a bit hardcoded, so it is not available without hacking on it.')
        print(args.prune)
        from explainfix import channelprune
        from deepfix.weight_saliency import costfn_multiclass
        a = sum([x.numel() for x in cfg.model.parameters()])
        channelprune(cfg.model, pct=5, grad_cost_fn=costfn_multiclass,
                     loader=cfg.train_loader, device=cfg.device, num_minibatches=10)
        b = sum([x.numel() for x in cfg.model.parameters()])
        assert a/b != 1
        print(f'done channelpruning.  {a/b}')

    cfg.train(cfg)
#             except Exception as e:
#                 print("=================================================================================================")
#                 print(e)
#                 print("=================================================================================================")
            
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    #  import IPython ; IPython.embed() ; import sys ; sys.exit()

    #  with T.profiler.profile(
    #      activities=[
    #          T.profiler.ProfilerActivity.CPU,
    #          T.profiler.ProfilerActivity.CUDA,
    #      ], with_modules=True,
    #  ) as p:
    #      cfg.train(cfg)
    #  print(p.key_averages().table(
    #      sort_by="self_cuda_time_total", row_limit=-1))


if __name__ == "__main__":
    main()
# Out:
# TrainOptions(epochs=50, start_epoch=0, device='cuda', dset='chexpert_small:.01:.01', opt='Adam:lr=0.001', lossfn='chexpert_uignore', loss_reg='none', model='waveletres18:imagenet:1:14', deepfix='off', experiment_id='model_waveletres18:imagenet:1:14_in_ch_1out_ch_14', prune='off')
# Checkpoint ./results/model_waveletres18:imagenet:1:14_in_ch_1out_ch_14/checkpoints/epoch_0.pth
# 100%|██████████| 149/149 [00:31<00:00,  4.72it/s]
# 100%|██████████| 149/149 [00:41<00:00,  3.57it/s]
# 100%|██████████| 16/16 [00:05<00:00,  2.96it/s]
# INFO:simplepytorch.logging_tools:DataLogger writing to file: /ocean/projects/cie160013p/elvinj/DeepFix/deepfix/results/model_waveletres18:imagenet:1:14_in_ch_1out_ch_14/log/20220130T025054.366696_perf.csv
# epoch:    0, seconds_training_epoch: nan
# 	TRAIN RESULTS: train_Loss:  101.09949, train_Num Samples:  2234.00000, train_MCC No Finding: -0.00156, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  0.00807, train_MCC Lung Opacity:  0.00329, train_MCC Lung Lesion:  0.05615, train_MCC Edema:  nan, train_MCC Consolidation: -0.01596, train_MCC Pneumonia:  0.00437, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  0.01363, train_MCC Pleural Effusion:  0.07162, train_MCC Pleural Other:  0.00615, train_MCC Fracture:  0.00614, train_MCC Support Devices:  0.04679, train_MCC AVG:  nan, train_Precision No Finding:  0.11111, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.12243, train_Precision Lung Opacity:  0.48798, train_Precision Lung Lesion:  0.33333, train_Precision Edema:  0.00000, train_Precision Consolidation:  0.06835, train_Precision Pneumonia:  0.02809, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.09257, train_Precision Pleural Effusion:  0.41425, train_Precision Pleural Other:  0.01193, train_Precision Fracture:  0.04039, train_Precision Support Devices:  0.53596, train_Precision AVG:  0.16046, train_Recall No Finding:  0.00376, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  1.00000, train_Recall Lung Opacity:  0.32486, train_Recall Lung Lesion:  0.01163, train_Recall Edema:  0.00000, train_Recall Consolidation:  0.12418, train_Recall Pneumonia:  0.91228, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  1.00000, train_Recall Pleural Effusion:  0.64908, train_Recall Pleural Other:  0.29167, train_Recall Fracture:  1.00000, train_Recall Support Devices:  0.80601, train_Recall AVG:  0.43739, train_F1 No Finding:  0.00727, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  0.21815, train_F1 Lung Opacity:  0.39005, train_F1 Lung Lesion:  0.02247, train_F1 Edema:  nan, train_F1 Consolidation:  0.08817, train_F1 Pneumonia:  0.05451, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  0.16945, train_F1 Pleural Effusion:  0.50574, train_F1 Pleural Other:  0.02291, train_F1 Fracture:  0.07765, train_F1 Support Devices:  0.64381, train_F1 AVG:  nan, train_Acc No Finding:  0.87780, train_Acc Enlarged Cardiomediastinum:  0.94542, train_Acc Cardiomegaly:  0.12284, train_Acc Lung Opacity:  0.50663, train_Acc Lung Lesion:  0.96078, train_Acc Edema:  0.76518, train_Acc Consolidation:  0.79742, train_Acc Pneumonia:  0.11828, train_Acc Atelectasis:  0.83068, train_Acc Pneumothorax:  0.09422, train_Acc Pleural Effusion:  0.51018, train_Acc Pleural Other:  0.72974, train_Acc Fracture:  0.04126, train_Acc Support Devices:  0.53282, train_Acc AVG:  0.55952, train_BAcc No Finding:  0.49985, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50027, train_BAcc Lung Opacity:  0.50154, train_BAcc Lung Lesion:  0.50534, train_BAcc Edema:  0.50000, train_BAcc Consolidation:  0.48962, train_BAcc Pneumonia:  0.50390, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.50100, train_BAcc Pleural Effusion:  0.53596, train_BAcc Pleural Other:  0.51311, train_BAcc Fracture:  0.50047, train_BAcc Support Devices:  0.51915, train_BAcc AVG:  0.50502
# 	VAL RESULTS: val_Loss:  100.98198, val_Num Samples:  2234.00000, val_MCC No Finding:  0.03317, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  nan, val_MCC Lung Opacity:  0.01990, val_MCC Lung Lesion: -0.01192, val_MCC Edema:  nan, val_MCC Consolidation:  0.00397, val_MCC Pneumonia: -0.00190, val_MCC Atelectasis:  nan, val_MCC Pneumothorax: -0.03551, val_MCC Pleural Effusion:  0.06405, val_MCC Pleural Other:  0.03131, val_MCC Fracture:  0.00745, val_MCC Support Devices:  0.07859, val_MCC AVG:  nan, val_Precision No Finding:  0.25000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.12772, val_Precision Lung Opacity:  0.49918, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.00000, val_Precision Consolidation:  0.08664, val_Precision Pneumonia:  0.03061, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.07486, val_Precision Pleural Effusion:  0.40686, val_Precision Pleural Other:  0.02337, val_Precision Fracture:  0.03955, val_Precision Support Devices:  0.55041, val_Precision AVG:  0.14923, val_Recall No Finding:  0.01230, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  1.00000, val_Recall Lung Opacity:  0.29254, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.00000, val_Recall Consolidation:  0.14545, val_Recall Pneumonia:  0.90476, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.98802, val_Recall Pleural Effusion:  0.67658, val_Recall Pleural Other:  0.37838, val_Recall Fracture:  1.00000, val_Recall Support Devices:  0.79779, val_Recall AVG:  0.44256, val_F1 No Finding:  0.02344, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  0.22651, val_F1 Lung Opacity:  0.36890, val_F1 Lung Lesion:  nan, val_F1 Edema:  nan, val_F1 Consolidation:  0.10860, val_F1 Pneumonia:  0.05922, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  0.13918, val_F1 Pleural Effusion:  0.50814, val_F1 Pleural Other:  0.04403, val_F1 Fracture:  0.07609, val_F1 Support Devices:  0.65140, val_F1 AVG:  nan, val_Acc No Finding:  0.88809, val_Acc Enlarged Cardiomediastinum:  0.95073, val_Acc Cardiomegaly:  0.12772, val_Acc Lung Opacity:  0.51617, val_Acc Lung Lesion:  0.95373, val_Acc Edema:  0.75509, val_Acc Consolidation:  0.79959, val_Acc Pneumonia:  0.11702, val_Acc Atelectasis:  0.83788, val_Acc Pneumothorax:  0.07772, val_Acc Pleural Effusion:  0.49786, val_Acc Pleural Other:  0.72414, val_Acc Fracture:  0.04084, val_Acc Support Devices:  0.54852, val_Acc AVG:  0.55965, val_BAcc No Finding:  0.50389, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50000, val_BAcc Lung Opacity:  0.50897, val_BAcc Lung Lesion:  0.49836, val_BAcc Edema:  0.50000, val_BAcc Consolidation:  0.50249, val_BAcc Pneumonia:  0.49841, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.49572, val_BAcc Pleural Effusion:  0.53166, val_BAcc Pleural Other:  0.55421, val_BAcc Fracture:  0.50070, val_BAcc Support Devices:  0.53331, val_BAcc AVG:  0.50912
# 	TEST RESULTS: test_Loss:  11.05089, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity: -0.03050, test_MCC Lung Lesion:  nan, test_MCC Edema:  nan, test_MCC Consolidation:  0.04582, test_MCC Pneumonia:  0.04374, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  0.02481, test_MCC Pleural Effusion:  0.07592, test_MCC Pleural Other: -0.03718, test_MCC Fracture:  nan, test_MCC Support Devices:  0.04822, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.29060, test_Precision Lung Opacity:  0.51471, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.00000, test_Precision Consolidation:  0.18519, test_Precision Pneumonia:  0.03604, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.03478, test_Precision Pleural Effusion:  0.31013, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.46995, test_Precision AVG:  0.13153, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  1.00000, test_Recall Lung Opacity:  0.27778, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.00000, test_Recall Consolidation:  0.15152, test_Recall Pneumonia:  1.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  1.00000, test_Recall Pleural Effusion:  0.73134, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.80374, test_Recall AVG:  0.35460, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  0.45033, test_F1 Lung Opacity:  0.36082, test_F1 Lung Lesion:  nan, test_F1 Edema:  nan, test_F1 Consolidation:  0.16667, test_F1 Pneumonia:  0.06957, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  0.06723, test_F1 Pleural Effusion:  0.43556, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.59310, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.29060, test_Acc Lung Opacity:  0.47009, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.80769, test_Acc Consolidation:  0.78632, test_Acc Pneumonia:  0.08547, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.05128, test_Acc Pleural Effusion:  0.45726, test_Acc Pleural Other:  0.75214, test_Acc Fracture:  0.00000, test_Acc Support Devices:  0.49573, test_Acc AVG:  0.51587, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.48611, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.50000, test_BAcc Consolidation:  0.52103, test_BAcc Pneumonia:  0.52655, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50885, test_BAcc Pleural Effusion:  0.53932, test_BAcc Pleural Other:  0.37768, test_BAcc Fracture:  0.00000, test_BAcc Support Devices:  0.51998, test_BAcc AVG:  0.46282
# 100%|██████████| 149/149 [00:55<00:00,  2.70it/s]
# 100%|██████████| 149/149 [01:02<00:00,  2.39it/s]
# 100%|██████████| 16/16 [00:06<00:00,  2.51it/s]
# epoch:    1, seconds_training_epoch: 55.1783
# 	TRAIN RESULTS: train_Loss:  54.38203, train_Num Samples:  2234.00000, train_MCC No Finding: -0.00778, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  nan, train_MCC Lung Opacity:  0.12488, train_MCC Lung Lesion:  0.05615, train_MCC Edema:  0.08903, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis: -0.02329, train_MCC Pneumothorax: -0.02038, train_MCC Pleural Effusion:  0.11229, train_MCC Pleural Other: -0.00837, train_MCC Fracture: -0.01570, train_MCC Support Devices:  0.17307, train_MCC AVG:  nan, train_Precision No Finding:  0.00000, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.55019, train_Precision Lung Lesion:  0.33333, train_Precision Edema:  0.45161, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.03846, train_Precision Pleural Effusion:  0.51987, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.59417, train_Precision AVG:  0.17769, train_Recall No Finding:  0.00000, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.54708, train_Recall Lung Lesion:  0.01163, train_Recall Edema:  0.05657, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.00493, train_Recall Pleural Effusion:  0.19264, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.68240, train_Recall AVG:  0.10680, train_F1 No Finding:  nan, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.54863, train_F1 Lung Lesion:  0.02247, train_F1 Edema:  0.10054, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  0.00873, train_F1 Pleural Effusion:  0.28111, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.63524, train_F1 AVG:  nan, train_Acc No Finding:  0.88048, train_Acc Enlarged Cardiomediastinum:  0.94542, train_Acc Cardiomegaly:  0.87763, train_Acc Lung Opacity:  0.56287, train_Acc Lung Lesion:  0.96078, train_Acc Edema:  0.76233, train_Acc Consolidation:  0.92113, train_Acc Pneumonia:  0.97214, train_Acc Atelectasis:  0.82803, train_Acc Pneumothorax:  0.89668, train_Acc Pleural Effusion:  0.61961, train_Acc Pleural Other:  0.98280, train_Acc Fracture:  0.95381, train_Acc Support Devices:  0.58948, train_Acc AVG:  0.83951, train_BAcc No Finding:  0.49975, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50000, train_BAcc Lung Opacity:  0.56243, train_BAcc Lung Lesion:  0.50534, train_BAcc Edema:  0.51774, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.49840, train_BAcc Pneumothorax:  0.49619, train_BAcc Pleural Effusion:  0.54038, train_BAcc Pleural Other:  0.49680, train_BAcc Fracture:  0.49696, train_BAcc Support Devices:  0.58483, train_BAcc AVG:  0.51420
# 	VAL RESULTS: val_Loss:  132.23853, val_Num Samples:  2234.00000, val_MCC No Finding:  nan, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  0.05048, val_MCC Lung Opacity:  nan, val_MCC Lung Lesion:  nan, val_MCC Edema:  nan, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  nan, val_MCC Pleural Effusion:  nan, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  nan, val_MCC AVG:  nan, val_Precision No Finding:  0.00000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.19149, val_Precision Lung Opacity:  0.48336, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.24491, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.38337, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.52875, val_Precision AVG:  0.13085, val_Recall No Finding:  0.00000, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.09783, val_Recall Lung Opacity:  1.00000, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  1.00000, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  1.00000, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  1.00000, val_Recall AVG:  0.29270, val_F1 No Finding:  nan, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  0.12950, val_F1 Lung Opacity:  0.65171, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.39346, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  0.55426, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.69174, val_F1 AVG:  nan, val_Acc No Finding:  0.89078, val_Acc Enlarged Cardiomediastinum:  0.95073, val_Acc Cardiomegaly:  0.83202, val_Acc Lung Opacity:  0.48336, val_Acc Lung Lesion:  0.95687, val_Acc Edema:  0.24491, val_Acc Consolidation:  0.91607, val_Acc Pneumonia:  0.96928, val_Acc Atelectasis:  0.83788, val_Acc Pneumothorax:  0.92454, val_Acc Pleural Effusion:  0.38337, val_Acc Pleural Other:  0.98321, val_Acc Fracture:  0.96050, val_Acc Support Devices:  0.52875, val_Acc AVG:  0.77588, val_BAcc No Finding:  0.50000, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.51867, val_BAcc Lung Opacity:  0.50000, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.50000, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50000, val_BAcc Pleural Effusion:  0.50000, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.50000, val_BAcc AVG:  0.50133
# 	TEST RESULTS: test_Loss:  17.12442, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  0.11634, test_MCC Lung Opacity:  nan, test_MCC Lung Lesion:  nan, test_MCC Edema:  nan, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  nan, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  nan, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.50000, test_Precision Lung Opacity:  0.53846, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.19231, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.28632, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.45726, test_Precision AVG:  0.14103, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.10294, test_Recall Lung Opacity:  1.00000, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  1.00000, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  1.00000, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  1.00000, test_Recall AVG:  0.29307, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  0.17073, test_F1 Lung Opacity:  0.70000, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.32258, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.44518, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.62757, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.53846, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.19231, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.28632, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.45726, test_Acc AVG:  0.71398, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.53039, test_BAcc Lung Opacity:  0.50000, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.50000, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.50000, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.50000, test_BAcc AVG:  0.50217
# 100%|██████████| 149/149 [00:51<00:00,  2.87it/s]
# 100%|██████████| 149/149 [01:09<00:00,  2.16it/s]
# 100%|██████████| 16/16 [00:07<00:00,  2.02it/s]
# epoch:    2, seconds_training_epoch: 51.9886
# 	TRAIN RESULTS: train_Loss:  52.63312, train_Num Samples:  2234.00000, train_MCC No Finding:  nan, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  nan, train_MCC Lung Opacity:  0.19485, train_MCC Lung Lesion:  nan, train_MCC Edema:  0.08247, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  nan, train_MCC Pleural Effusion:  0.19420, train_MCC Pleural Other:  nan, train_MCC Fracture:  nan, train_MCC Support Devices:  0.25404, train_MCC AVG:  nan, train_Precision No Finding:  0.00000, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.58909, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.44643, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.00000, train_Precision Pleural Effusion:  0.54713, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.63199, train_Precision AVG:  0.15819, train_Recall No Finding:  0.00000, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.56968, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.05051, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.00000, train_Recall Pleural Effusion:  0.36319, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.69871, train_Recall AVG:  0.12015, train_F1 No Finding:  nan, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.57922, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.09074, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  nan, train_F1 Pleural Effusion:  0.43658, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.66368, train_F1 AVG:  nan, train_Acc No Finding:  0.88093, train_Acc Enlarged Cardiomediastinum:  0.94542, train_Acc Cardiomegaly:  0.87763, train_Acc Lung Opacity:  0.59808, train_Acc Lung Lesion:  0.96123, train_Acc Edema:  0.76233, train_Acc Consolidation:  0.92113, train_Acc Pneumonia:  0.97214, train_Acc Atelectasis:  0.83068, train_Acc Pneumothorax:  0.90760, train_Acc Pleural Effusion:  0.63809, train_Acc Pleural Other:  0.98914, train_Acc Fracture:  0.95964, train_Acc Support Devices:  0.62905, train_Acc AVG:  0.84808, train_BAcc No Finding:  0.50000, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50000, train_BAcc Lung Opacity:  0.59728, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.51564, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.50000, train_BAcc Pleural Effusion:  0.58707, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50000, train_BAcc Support Devices:  0.62556, train_BAcc AVG:  0.52325
# 	VAL RESULTS: val_Loss:  53.46054, val_Num Samples:  2234.00000, val_MCC No Finding:  nan, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  nan, val_MCC Lung Opacity:  0.16438, val_MCC Lung Lesion:  nan, val_MCC Edema:  0.26760, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  nan, val_MCC Pleural Effusion:  0.26096, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.23657, val_MCC AVG:  nan, val_Precision No Finding:  0.00000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.00000, val_Precision Lung Opacity:  0.52991, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.41441, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.51312, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.58352, val_Precision AVG:  0.14578, val_Recall No Finding:  0.00000, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.00000, val_Recall Lung Opacity:  0.82983, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.53385, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  0.65428, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.90824, val_Recall AVG:  0.20901, val_F1 No Finding:  nan, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  nan, val_F1 Lung Opacity:  0.64680, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.46661, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  0.57516, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.71054, val_F1 AVG:  nan, val_Acc No Finding:  0.89078, val_Acc Enlarged Cardiomediastinum:  0.95073, val_Acc Cardiomegaly:  0.87228, val_Acc Lung Opacity:  0.56192, val_Acc Lung Lesion:  0.95687, val_Acc Edema:  0.70109, val_Acc Consolidation:  0.91607, val_Acc Pneumonia:  0.96928, val_Acc Atelectasis:  0.83788, val_Acc Pneumothorax:  0.92454, val_Acc Pleural Effusion:  0.62945, val_Acc Pleural Other:  0.98321, val_Acc Fracture:  0.96050, val_Acc Support Devices:  0.60872, val_Acc AVG:  0.84024, val_BAcc No Finding:  0.50000, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50000, val_BAcc Lung Opacity:  0.57055, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.64459, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50000, val_BAcc Pleural Effusion:  0.63415, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.59044, val_BAcc AVG:  0.53141
# 	TEST RESULTS: test_Loss:  7.45469, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity:  0.33580, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.26086, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.38277, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.18341, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.00000, test_Precision Lung Opacity:  0.64118, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.35294, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.46847, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.50000, test_Precision AVG:  0.14018, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.00000, test_Recall Lung Opacity:  0.86508, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.53333, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.77612, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.89720, test_Recall AVG:  0.21941, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  nan, test_F1 Lung Opacity:  0.73649, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.42478, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.58427, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.64214, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.66667, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.72222, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.68376, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.54274, test_Acc AVG:  0.79548, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.65013, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.65026, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.71141, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.57065, test_BAcc AVG:  0.54160
# 100%|██████████| 149/149 [00:59<00:00,  2.51it/s]
# 100%|██████████| 149/149 [00:59<00:00,  2.52it/s]
# 100%|██████████| 16/16 [00:07<00:00,  2.24it/s]
# epoch:    3, seconds_training_epoch: 59.4482
# 	TRAIN RESULTS: train_Loss:  52.31717, train_Num Samples:  2234.00000, train_MCC No Finding:  nan, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  nan, train_MCC Lung Opacity:  0.17285, train_MCC Lung Lesion:  nan, train_MCC Edema:  0.11379, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  nan, train_MCC Pleural Effusion:  0.20729, train_MCC Pleural Other:  nan, train_MCC Fracture:  nan, train_MCC Support Devices:  0.24946, train_MCC AVG:  nan, train_Precision No Finding:  0.00000, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.57741, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.46591, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.00000, train_Precision Pleural Effusion:  0.56038, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.62974, train_Precision AVG:  0.15953, train_Recall No Finding:  0.00000, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.55838, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.08283, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.00000, train_Recall Pleural Effusion:  0.36442, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.69785, train_Recall AVG:  0.12168, train_F1 No Finding:  nan, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.56774, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.14065, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  nan, train_F1 Pleural Effusion:  0.44164, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.66205, train_F1 AVG:  nan, train_Acc No Finding:  0.88093, train_Acc Enlarged Cardiomediastinum:  0.94542, train_Acc Cardiomegaly:  0.87763, train_Acc Lung Opacity:  0.58711, train_Acc Lung Lesion:  0.96123, train_Acc Edema:  0.76233, train_Acc Consolidation:  0.92113, train_Acc Pneumonia:  0.97214, train_Acc Atelectasis:  0.83068, train_Acc Pneumothorax:  0.90760, train_Acc Pleural Effusion:  0.64424, train_Acc Pleural Other:  0.98914, train_Acc Fracture:  0.95964, train_Acc Support Devices:  0.62680, train_Acc AVG:  0.84757, train_BAcc No Finding:  0.50000, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50000, train_BAcc Lung Opacity:  0.58630, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.52684, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.50000, train_BAcc Pleural Effusion:  0.59232, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50000, train_BAcc Support Devices:  0.62324, train_BAcc AVG:  0.52348
# 	VAL RESULTS: val_Loss:  53.81860, val_Num Samples:  2234.00000, val_MCC No Finding:  nan, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  nan, val_MCC Lung Opacity:  0.05790, val_MCC Lung Lesion:  nan, val_MCC Edema:  nan, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  nan, val_MCC Pleural Effusion:  0.11346, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.24770, val_MCC AVG:  nan, val_Precision No Finding:  0.00000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.00000, val_Precision Lung Opacity:  0.67347, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.00000, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.61607, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.70868, val_Precision AVG:  0.14273, val_Recall No Finding:  0.00000, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.00000, val_Recall Lung Opacity:  0.03155, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.00000, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  0.08550, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.42991, val_Recall AVG:  0.03907, val_F1 No Finding:  nan, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  nan, val_F1 Lung Opacity:  0.06027, val_F1 Lung Lesion:  nan, val_F1 Edema:  nan, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  0.15016, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.53517, val_F1 AVG:  nan, val_Acc No Finding:  0.89078, val_Acc Enlarged Cardiomediastinum:  0.95073, val_Acc Cardiomegaly:  0.87228, val_Acc Lung Opacity:  0.52449, val_Acc Lung Lesion:  0.95687, val_Acc Edema:  0.75509, val_Acc Consolidation:  0.91607, val_Acc Pneumonia:  0.96928, val_Acc Atelectasis:  0.83788, val_Acc Pneumothorax:  0.92454, val_Acc Pleural Effusion:  0.62898, val_Acc Pleural Other:  0.98321, val_Acc Fracture:  0.96050, val_Acc Support Devices:  0.60512, val_Acc AVG:  0.84113, val_BAcc No Finding:  0.50000, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50000, val_BAcc Lung Opacity:  0.50862, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.50000, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50000, val_BAcc Pleural Effusion:  0.52619, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.61581, val_BAcc AVG:  0.51076
# 	TEST RESULTS: test_Loss:  7.26222, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity:  0.13680, test_MCC Lung Lesion:  nan, test_MCC Edema:  nan, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.11912, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.25359, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.00000, test_Precision Lung Opacity:  1.00000, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.00000, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.55556, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.65672, test_Precision AVG:  0.15802, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.00000, test_Recall Lung Opacity:  0.03968, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.00000, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.07463, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.41121, test_Recall AVG:  0.03754, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  nan, test_F1 Lung Opacity:  0.07634, test_F1 Lung Lesion:  nan, test_F1 Edema:  nan, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.13158, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.50575, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.48291, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.80769, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.71795, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.63248, test_Acc AVG:  0.79731, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.51984, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.50000, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.52534, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.61506, test_BAcc AVG:  0.51145
# 100%|██████████| 149/149 [01:00<00:00,  2.45it/s]
# 100%|██████████| 149/149 [00:50<00:00,  2.98it/s]
# 100%|██████████| 16/16 [00:06<00:00,  2.29it/s]
# epoch:    4, seconds_training_epoch: 60.8609
# 	TRAIN RESULTS: train_Loss:  52.18915, train_Num Samples:  2234.00000, train_MCC No Finding:  nan, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  nan, train_MCC Lung Opacity:  0.20439, train_MCC Lung Lesion:  nan, train_MCC Edema:  0.08693, train_MCC Consolidation:  nan, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  nan, train_MCC Pneumothorax:  nan, train_MCC Pleural Effusion:  0.21376, train_MCC Pleural Other:  nan, train_MCC Fracture:  nan, train_MCC Support Devices:  0.27241, train_MCC AVG:  nan, train_Precision No Finding:  0.00000, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.00000, train_Precision Lung Opacity:  0.59199, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.42667, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.00000, train_Precision Pneumothorax:  0.00000, train_Precision Pleural Effusion:  0.56425, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.64218, train_Precision AVG:  0.15893, train_Recall No Finding:  0.00000, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.00000, train_Recall Lung Opacity:  0.58475, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.06465, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.00000, train_Recall Pneumothorax:  0.00000, train_Recall Pleural Effusion:  0.37178, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.69785, train_Recall AVG:  0.12279, train_F1 No Finding:  nan, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  nan, train_F1 Lung Opacity:  0.58835, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.11228, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  nan, train_F1 Pneumothorax:  nan, train_F1 Pleural Effusion:  0.44822, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.66886, train_F1 AVG:  nan, train_Acc No Finding:  0.88093, train_Acc Enlarged Cardiomediastinum:  0.94542, train_Acc Cardiomegaly:  0.87763, train_Acc Lung Opacity:  0.60265, train_Acc Lung Lesion:  0.96123, train_Acc Edema:  0.75996, train_Acc Consolidation:  0.92113, train_Acc Pneumonia:  0.97214, train_Acc Atelectasis:  0.83068, train_Acc Pneumothorax:  0.90760, train_Acc Pleural Effusion:  0.64661, train_Acc Pleural Other:  0.98914, train_Acc Fracture:  0.95964, train_Acc Support Devices:  0.63804, train_Acc AVG:  0.84949, train_BAcc No Finding:  0.50000, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.50000, train_BAcc Lung Opacity:  0.60215, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.51899, train_BAcc Consolidation:  0.50000, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.50000, train_BAcc Pneumothorax:  0.50000, train_BAcc Pleural Effusion:  0.59561, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50000, train_BAcc Support Devices:  0.63505, train_BAcc AVG:  0.52513
# 	VAL RESULTS: val_Loss:  61.26650, val_Num Samples:  2234.00000, val_MCC No Finding:  nan, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  0.06009, val_MCC Lung Opacity:  0.19404, val_MCC Lung Lesion:  nan, val_MCC Edema:  0.27212, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  nan, val_MCC Pleural Effusion:  0.21109, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.21691, val_MCC AVG:  nan, val_Precision No Finding:  0.00000, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.35294, val_Precision Lung Opacity:  0.53762, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.35086, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.00000, val_Precision Pleural Effusion:  0.42873, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.57376, val_Precision AVG:  0.16028, val_Recall No Finding:  0.00000, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.02174, val_Recall Lung Opacity:  0.84704, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.78723, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.00000, val_Recall Pleural Effusion:  0.93556, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.92523, val_Recall AVG:  0.25120, val_F1 No Finding:  nan, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  0.04096, val_F1 Lung Opacity:  0.65776, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.48539, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  nan, val_F1 Pleural Effusion:  0.58801, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.70829, val_F1 AVG:  nan, val_Acc No Finding:  0.89078, val_Acc Enlarged Cardiomediastinum:  0.95073, val_Acc Cardiomegaly:  0.86997, val_Acc Lung Opacity:  0.57394, val_Acc Lung Lesion:  0.95687, val_Acc Edema:  0.59119, val_Acc Consolidation:  0.91607, val_Acc Pneumonia:  0.96928, val_Acc Atelectasis:  0.83788, val_Acc Pneumothorax:  0.92454, val_Acc Pleural Effusion:  0.49739, val_Acc Pleural Other:  0.98321, val_Acc Fracture:  0.96050, val_Acc Support Devices:  0.59704, val_Acc AVG:  0.82281, val_BAcc No Finding:  0.50000, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.50795, val_BAcc Lung Opacity:  0.58273, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.65742, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.50000, val_BAcc Pleural Effusion:  0.58026, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.57701, val_BAcc AVG:  0.52896
# 	TEST RESULTS: test_Loss:  7.96462, test_Num Samples:  234.00000, test_MCC No Finding:  nan, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  nan, test_MCC Lung Opacity:  0.30369, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.22221, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.23793, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.21135, test_MCC AVG:  nan, test_Precision No Finding:  0.00000, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.00000, test_Precision Lung Opacity:  0.63636, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.27132, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.34239, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.51075, test_Precision AVG:  0.12577, test_Recall No Finding:  0.00000, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.00000, test_Recall Lung Opacity:  0.83333, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.77778, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.94030, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.88785, test_Recall AVG:  0.24566, test_F1 No Finding:  nan, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  nan, test_F1 Lung Opacity:  0.72165, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.40230, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.50199, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.64846, test_F1 AVG:  nan, test_Acc No Finding:  0.83761, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70940, test_Acc Lung Opacity:  0.65385, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.55556, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.46581, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.55983, test_Acc AVG:  0.76832, test_BAcc No Finding:  0.50000, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.50000, test_BAcc Lung Opacity:  0.63889, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.64021, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.60787, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.58566, test_BAcc AVG:  0.53376
# 100%|██████████| 149/149 [01:05<00:00,  2.29it/s]
# 100%|██████████| 149/149 [00:50<00:00,  2.97it/s]
# 100%|██████████| 16/16 [00:05<00:00,  2.71it/s]
# epoch:    5, seconds_training_epoch: 65.2123
# ...
# 	VAL RESULTS: val_Loss:  56.35670, val_Num Samples:  2234.00000, val_MCC No Finding:  0.16250, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  0.10732, val_MCC Lung Opacity:  0.19769, val_MCC Lung Lesion:  nan, val_MCC Edema:  0.12719, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  nan, val_MCC Pneumothorax:  0.06613, val_MCC Pleural Effusion:  0.29402, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.30781, val_MCC AVG:  nan, val_Precision No Finding:  0.35106, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.25150, val_Precision Lung Opacity:  0.56375, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.50562, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.00000, val_Precision Pneumothorax:  0.26316, val_Precision Pleural Effusion:  0.52845, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.63784, val_Precision AVG:  0.22153, val_Recall No Finding:  0.13525, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.15217, val_Recall Lung Opacity:  0.70172, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.08704, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.00000, val_Recall Pneumothorax:  0.02994, val_Recall Pleural Effusion:  0.67906, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.80204, val_Recall AVG:  0.18480, val_F1 No Finding:  0.19527, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  0.18962, val_F1 Lung Opacity:  0.62521, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.14851, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  nan, val_F1 Pneumothorax:  0.05376, val_F1 Pleural Effusion:  0.59436, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.71058, val_F1 AVG:  nan, val_Acc No Finding:  0.87825, val_Acc Enlarged Cardiomediastinum:  0.95073, val_Acc Cardiomegaly:  0.83387, val_Acc Lung Opacity:  0.59335, val_Acc Lung Lesion:  0.95687, val_Acc Edema:  0.75557, val_Acc Consolidation:  0.91607, val_Acc Pneumonia:  0.96928, val_Acc Atelectasis:  0.83788, val_Acc Pneumothorax:  0.92047, val_Acc Pleural Effusion:  0.64466, val_Acc Pleural Other:  0.98321, val_Acc Fracture:  0.96050, val_Acc Support Devices:  0.65454, val_Acc AVG:  0.84680, val_BAcc No Finding:  0.55230, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.54293, val_BAcc Lung Opacity:  0.59684, val_BAcc Lung Lesion:  0.50000, val_BAcc Edema:  0.52972, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50000, val_BAcc Pneumothorax:  0.51155, val_BAcc Pleural Effusion:  0.65116, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.64554, val_BAcc AVG:  0.53786
# 	TEST RESULTS: test_Loss:  7.53196, test_Num Samples:  234.00000, test_MCC No Finding:  0.13321, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  0.09781, test_MCC Lung Opacity:  0.33939, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.21857, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  nan, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.30544, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.21513, test_MCC AVG:  nan, test_Precision No Finding:  0.35714, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.44444, test_Precision Lung Opacity:  0.69919, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.60000, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.00000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.44898, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.54745, test_Precision AVG:  0.22123, test_Recall No Finding:  0.13158, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.11765, test_Recall Lung Opacity:  0.68254, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.13333, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.00000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.65672, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.70093, test_Recall AVG:  0.17305, test_F1 No Finding:  0.19231, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  0.18605, test_F1 Lung Opacity:  0.69076, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.21818, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  nan, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.53333, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.61475, test_F1 AVG:  nan, test_Acc No Finding:  0.82051, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.70085, test_Acc Lung Opacity:  0.67094, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.81624, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.65812, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.67094, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.59829, test_Acc AVG:  0.80372, test_BAcc No Finding:  0.54283, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.52870, test_BAcc Lung Opacity:  0.66997, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.55608, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.50000, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.66668, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.60637, test_BAcc AVG:  0.54076
# 100%|██████████| 149/149 [01:01<00:00,  2.44it/s]
# 100%|██████████| 149/149 [00:50<00:00,  2.93it/s]
# 100%|██████████| 16/16 [00:07<00:00,  2.21it/s]
# epoch:   50, seconds_training_epoch: 61.0265
# 	TRAIN RESULTS: train_Loss:  41.05231, train_Num Samples:  2234.00000, train_MCC No Finding:  0.55944, train_MCC Enlarged Cardiomediastinum:  nan, train_MCC Cardiomegaly:  0.32650, train_MCC Lung Opacity:  0.34699, train_MCC Lung Lesion:  nan, train_MCC Edema:  0.44668, train_MCC Consolidation: -0.01152, train_MCC Pneumonia:  nan, train_MCC Atelectasis:  0.09703, train_MCC Pneumothorax:  0.31221, train_MCC Pleural Effusion:  0.52058, train_MCC Pleural Other:  nan, train_MCC Fracture:  nan, train_MCC Support Devices:  0.64866, train_MCC AVG:  nan, train_Precision No Finding:  0.72928, train_Precision Enlarged Cardiomediastinum:  0.00000, train_Precision Cardiomegaly:  0.65854, train_Precision Lung Opacity:  0.64086, train_Precision Lung Lesion:  0.00000, train_Precision Edema:  0.66964, train_Precision Consolidation:  0.00000, train_Precision Pneumonia:  0.00000, train_Precision Atelectasis:  0.56250, train_Precision Pneumothorax:  0.67308, train_Precision Pleural Effusion:  0.71447, train_Precision Pleural Other:  0.00000, train_Precision Fracture:  0.00000, train_Precision Support Devices:  0.83550, train_Precision AVG:  0.39170, train_Recall No Finding:  0.49624, train_Recall Enlarged Cardiomediastinum:  0.00000, train_Recall Cardiomegaly:  0.20611, train_Recall Lung Opacity:  0.73258, train_Recall Lung Lesion:  0.00000, train_Recall Edema:  0.45455, train_Recall Consolidation:  0.00000, train_Recall Pneumonia:  0.00000, train_Recall Atelectasis:  0.02821, train_Recall Pneumothorax:  0.17241, train_Recall Pleural Effusion:  0.69080, train_Recall Pleural Other:  0.00000, train_Recall Fracture:  0.00000, train_Recall Support Devices:  0.82833, train_Recall AVG:  0.25780, train_F1 No Finding:  0.59060, train_F1 Enlarged Cardiomediastinum:  nan, train_F1 Cardiomegaly:  0.31395, train_F1 Lung Opacity:  0.68366, train_F1 Lung Lesion:  nan, train_F1 Edema:  0.54152, train_F1 Consolidation:  nan, train_F1 Pneumonia:  nan, train_F1 Atelectasis:  0.05373, train_F1 Pneumothorax:  0.27451, train_F1 Pleural Effusion:  0.70243, train_F1 Pleural Other:  nan, train_F1 Fracture:  nan, train_F1 Support Devices:  0.83190, train_F1 AVG:  nan, train_Acc No Finding:  0.91808, train_Acc Enlarged Cardiomediastinum:  0.94542, train_Acc Cardiomegaly:  0.88977, train_Acc Lung Opacity:  0.67078, train_Acc Lung Lesion:  0.96123, train_Acc Edema:  0.81926, train_Acc Consolidation:  0.91959, train_Acc Pneumonia:  0.97214, train_Acc Atelectasis:  0.83174, train_Acc Pneumothorax:  0.91579, train_Acc Pleural Effusion:  0.77404, train_Acc Pleural Other:  0.98914, train_Acc Fracture:  0.95964, train_Acc Support Devices:  0.82464, train_Acc AVG:  0.88509, train_BAcc No Finding:  0.73567, train_BAcc Enlarged Cardiomediastinum:  0.50000, train_BAcc Cardiomegaly:  0.59560, train_BAcc Lung Opacity:  0.67251, train_BAcc Lung Lesion:  0.50000, train_BAcc Edema:  0.69286, train_BAcc Consolidation:  0.49916, train_BAcc Pneumonia:  0.50000, train_BAcc Atelectasis:  0.51187, train_BAcc Pneumothorax:  0.58194, train_BAcc Pleural Effusion:  0.75859, train_BAcc Pleural Other:  0.50000, train_BAcc Fracture:  0.50000, train_BAcc Support Devices:  0.82446, train_BAcc AVG:  0.59805
# 	VAL RESULTS: val_Loss:  62.81825, val_Num Samples:  2234.00000, val_MCC No Finding:  0.23946, val_MCC Enlarged Cardiomediastinum:  nan, val_MCC Cardiomegaly:  0.10650, val_MCC Lung Opacity:  0.12138, val_MCC Lung Lesion: -0.00450, val_MCC Edema:  0.20807, val_MCC Consolidation:  nan, val_MCC Pneumonia:  nan, val_MCC Atelectasis:  0.05161, val_MCC Pneumothorax:  0.00862, val_MCC Pleural Effusion:  0.25037, val_MCC Pleural Other:  nan, val_MCC Fracture:  nan, val_MCC Support Devices:  0.19559, val_MCC AVG:  nan, val_Precision No Finding:  0.33186, val_Precision Enlarged Cardiomediastinum:  0.00000, val_Precision Cardiomegaly:  0.30233, val_Precision Lung Opacity:  0.58727, val_Precision Lung Lesion:  0.00000, val_Precision Edema:  0.39292, val_Precision Consolidation:  0.00000, val_Precision Pneumonia:  0.00000, val_Precision Atelectasis:  0.29730, val_Precision Pneumothorax:  0.11111, val_Precision Pleural Effusion:  0.57006, val_Precision Pleural Other:  0.00000, val_Precision Fracture:  0.00000, val_Precision Support Devices:  0.70784, val_Precision AVG:  0.23576, val_Recall No Finding:  0.30738, val_Recall Enlarged Cardiomediastinum:  0.00000, val_Recall Cardiomegaly:  0.09420, val_Recall Lung Opacity:  0.30880, val_Recall Lung Lesion:  0.00000, val_Recall Edema:  0.42940, val_Recall Consolidation:  0.00000, val_Recall Pneumonia:  0.00000, val_Recall Atelectasis:  0.03560, val_Recall Pneumothorax:  0.00599, val_Recall Pleural Effusion:  0.44362, val_Recall Pleural Other:  0.00000, val_Recall Fracture:  0.00000, val_Recall Support Devices:  0.30671, val_Recall AVG:  0.13798, val_F1 No Finding:  0.31915, val_F1 Enlarged Cardiomediastinum:  nan, val_F1 Cardiomegaly:  0.14365, val_F1 Lung Opacity:  0.40476, val_F1 Lung Lesion:  nan, val_F1 Edema:  0.41035, val_F1 Consolidation:  nan, val_F1 Pneumonia:  nan, val_F1 Atelectasis:  0.06358, val_F1 Pneumothorax:  0.01136, val_F1 Pleural Effusion:  0.49895, val_F1 Pleural Other:  nan, val_F1 Fracture:  nan, val_F1 Support Devices:  0.42798, val_F1 AVG:  nan, val_Acc No Finding:  0.85676, val_Acc Enlarged Cardiomediastinum:  0.95073, val_Acc Cardiomegaly:  0.85655, val_Acc Lung Opacity:  0.56100, val_Acc Lung Lesion:  0.95642, val_Acc Edema:  0.69777, val_Acc Consolidation:  0.91607, val_Acc Pneumonia:  0.96928, val_Acc Atelectasis:  0.83001, val_Acc Pneumothorax:  0.92137, val_Acc Pleural Effusion:  0.65843, val_Acc Pleural Other:  0.98321, val_Acc Fracture:  0.96050, val_Acc Support Devices:  0.56649, val_Acc AVG:  0.83462, val_BAcc No Finding:  0.61575, val_BAcc Enlarged Cardiomediastinum:  0.50000, val_BAcc Cardiomegaly:  0.53119, val_BAcc Lung Opacity:  0.55288, val_BAcc Lung Lesion:  0.49977, val_BAcc Edema:  0.60711, val_BAcc Consolidation:  0.50000, val_BAcc Pneumonia:  0.50000, val_BAcc Atelectasis:  0.50966, val_BAcc Pneumothorax:  0.50104, val_BAcc Pleural Effusion:  0.61780, val_BAcc Pleural Other:  0.50000, val_BAcc Fracture:  0.50000, val_BAcc Support Devices:  0.58234, val_BAcc AVG:  0.53697
# 	TEST RESULTS: test_Loss:  9.02588, test_Num Samples:  234.00000, test_MCC No Finding:  0.21303, test_MCC Enlarged Cardiomediastinum:  nan, test_MCC Cardiomegaly:  0.13436, test_MCC Lung Opacity:  0.18151, test_MCC Lung Lesion:  nan, test_MCC Edema:  0.18983, test_MCC Consolidation:  nan, test_MCC Pneumonia:  nan, test_MCC Atelectasis:  0.14271, test_MCC Pneumothorax:  nan, test_MCC Pleural Effusion:  0.37759, test_MCC Pleural Other:  nan, test_MCC Fracture:  nan, test_MCC Support Devices:  0.14567, test_MCC AVG:  nan, test_Precision No Finding:  0.38462, test_Precision Enlarged Cardiomediastinum:  0.00000, test_Precision Cardiomegaly:  0.66667, test_Precision Lung Opacity:  0.71429, test_Precision Lung Lesion:  0.00000, test_Precision Edema:  0.32727, test_Precision Consolidation:  0.00000, test_Precision Pneumonia:  0.00000, test_Precision Atelectasis:  0.80000, test_Precision Pneumothorax:  0.00000, test_Precision Pleural Effusion:  0.57377, test_Precision Pleural Other:  0.00000, test_Precision Fracture:  0.00000, test_Precision Support Devices:  0.63636, test_Precision AVG:  0.29307, test_Recall No Finding:  0.26316, test_Recall Enlarged Cardiomediastinum:  0.00000, test_Recall Cardiomegaly:  0.05882, test_Recall Lung Opacity:  0.27778, test_Recall Lung Lesion:  0.00000, test_Recall Edema:  0.40000, test_Recall Consolidation:  0.00000, test_Recall Pneumonia:  0.00000, test_Recall Atelectasis:  0.05000, test_Recall Pneumothorax:  0.00000, test_Recall Pleural Effusion:  0.52239, test_Recall Pleural Other:  0.00000, test_Recall Fracture:  0.00000, test_Recall Support Devices:  0.19626, test_Recall AVG:  0.12631, test_F1 No Finding:  0.31250, test_F1 Enlarged Cardiomediastinum:  nan, test_F1 Cardiomegaly:  0.10811, test_F1 Lung Opacity:  0.40000, test_F1 Lung Lesion:  nan, test_F1 Edema:  0.36000, test_F1 Consolidation:  nan, test_F1 Pneumonia:  nan, test_F1 Atelectasis:  0.09412, test_F1 Pneumothorax:  nan, test_F1 Pleural Effusion:  0.54688, test_F1 Pleural Other:  nan, test_F1 Fracture:  nan, test_F1 Support Devices:  0.30000, test_F1 AVG:  nan, test_Acc No Finding:  0.81197, test_Acc Enlarged Cardiomediastinum:  0.53419, test_Acc Cardiomegaly:  0.71795, test_Acc Lung Opacity:  0.55128, test_Acc Lung Lesion:  0.99573, test_Acc Edema:  0.72650, test_Acc Consolidation:  0.85897, test_Acc Pneumonia:  0.96581, test_Acc Atelectasis:  0.67094, test_Acc Pneumothorax:  0.96581, test_Acc Pleural Effusion:  0.75214, test_Acc Pleural Other:  0.99573, test_Acc Fracture:  1.00000, test_Acc Support Devices:  0.58120, test_Acc AVG:  0.79487, test_BAcc No Finding:  0.59076, test_BAcc Enlarged Cardiomediastinum:  0.50000, test_BAcc Cardiomegaly:  0.52339, test_BAcc Lung Opacity:  0.57407, test_BAcc Lung Lesion:  0.50000, test_BAcc Edema:  0.60212, test_BAcc Consolidation:  0.50000, test_BAcc Pneumonia:  0.50000, test_BAcc Atelectasis:  0.52175, test_BAcc Pneumothorax:  0.50000, test_BAcc Pleural Effusion:  0.68335, test_BAcc Pleural Other:  0.50000, test_BAcc Fracture:  0.50000, test_BAcc Support Devices:  0.55089, test_BAcc AVG:  0.53902
# Checkpoint ./results/model_waveletres18:imagenet:1:14_in_ch_1out_ch_14/checkpoints/epoch_50.pth
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# MODELS = {
#     ('effnetv2', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_effnetv2(pretrain, int(in_ch), int(out_ch))),
#     ('resnet50', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_resnet('resnet50', pretrain, int(in_ch), int(out_ch))),
#     ('resnet18', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_resnet('resnet18', pretrain, int(in_ch), int(out_ch))),
#     ('efficientnet-b0', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_efficientnetv1('efficientnet-b0', pretrain, int(in_ch), int(out_ch))),
#     ('efficientnet-b1', str, str, str): (
#         lambda pretrain, in_ch, out_ch: get_efficientnetv1('efficientnet-b1', pretrain, int(in_ch), int(out_ch))),
#     ('waveletres18', str, str, str): lambda pretrain, in_ch, out_ch: R(
#         pretrain, int(in_ch), int(out_ch)),
#     ('waveletmlp', str, str, str, str, str, str, str): (
#         lambda mlp_channels, in_ch, out_ch, wavelet_levels, patch_size, in_ch_mul, mlp_depth: get_DeepFixEnd2End(
#             int(in_ch), int(out_ch),
#             in_ch_multiplier=int(in_ch_mul), wavelet='db1',
#             wavelet_levels=int(wavelet_levels), wavelet_patch_size=int(patch_size),
#             mlp_depth=int(mlp_depth), mlp_channels=int(mlp_channels),
#             mlp_fix_weights='none', mlp_activation=None)
#         ),

#     #  ('waveletres18v2', str, str, str): lambda pretrain, in_ch, out_ch: (
#         #  DeepFixCompression(levels=8, wavelet='coif1', patch_size=1),
#         #  R2(pretrain, int(in_ch), int(out_ch))),
# }


# class R(T.nn.Module):
#     def __init__(self, pretrain, in_ch, out_ch):
#         super().__init__()
#         self.r = get_resnet('resnet18', pretrain, in_ch, out_ch,)
#         self.dwt = pyw.DWT(J=8, wave='coif1', mode='zero')

#     @staticmethod
#     def wavelet_coefficients_as_tensorimage(approx, detail, normalize=False):
#         B,C = approx.shape[:2]
#         fixed_dims = approx.shape[:-2] # num images in minibatch, num channels, etc
#         output_shape = fixed_dims + (
#             detail[0].shape[-2]*2,  # input img height
#             detail[0].shape[-1]*2)  # input img width
#         im = T.zeros(output_shape, device=approx.device, dtype=approx.dtype)
#         if normalize:
#             norm11 = lambda x: (x / max(x.min()*-1, x.max()))  # into [-1,+1] preserving sign
#             #  approx = norm11(approx)
#         im[..., :approx.shape[-2], :approx.shape[-1]] = approx if approx is not None else 0
#         for level in detail:
#             lh, hl, hh = level.unbind(-3)
#             h,w = lh.shape[-2:]
#             if normalize:
#                 lh, hl, hh = [norm11(x) for x in [lh, hl, hh]]
#             #  im[:h, :w] = approx
#             im[..., 0:h, w:w+w] = lh  # horizontal
#             im[..., h:h+h, :w] = hl  # vertical
#             im[..., h:h+h, w:w+w] = hh  # diagonal
#         return im

#     def forward(self, x):
#         x = self.wavelet_coefficients_as_tensorimage(*self.dwt(x))
#         return self.r(x)


# class R2(T.nn.Module):
#     def __init__(self, pretrain, in_ch, out_ch):
#         super().__init__()
#         self.r = get_resnet('resnet18', pretrain, in_ch, out_ch,)

#     def forward(self, x):
#         B,C,H = x.shape
#         x = x.unsqueeze(-1).repeat(1,1,1,H)
#         return self.r(x)


# class LossCheXpertIdentity(T.nn.Module):
#     def __init__(self, N):
#         super().__init__()
#         self.bce = T.nn.BCEWithLogitsLoss()
#         self.N = N

#     def forward(self, yhat, y):
#         # absolute max possible num patients in chexpert is 223414
#         # but let's just hash them into a smaller number of bins via modulo N
#         assert self.N == yhat.shape[1], \
#                 f'note: model must have {self.N} binary predictions per sample'
#         y_onehot = y.new_zeros(y.shape[0], self.N, dtype=T.float
#                                ).scatter_(1, y.long()%self.N, 1)
#         return self.bce(yhat[:, -1], y_onehot[:, -1])


# class LossCheXpertUignore(T.nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.bce = T.nn.BCEWithLogitsLoss()

#     def forward(self, yhat, y):
#         ignore = (y != 2)  # ignore uncertainty labels
#         return self.bce(yhat[ignore], y[ignore])


# def loss_intelmobileodt(yhat, y):
#     """BCE Loss with class balancing weights.

#     Not sure this actually helps

#     because Type 2 is the hardest class, it
#     has the most samples, and it separates Type 1 from Type 3.  Arguably, Type 2
#     samples are on the decision boundary between Type 1 and 3.
#     Class balancing weights make it harder to focus on class 2.
#     """
#     #  assert y.shape == yhat.shape, 'sanity check'
#     #  assert y.dtype == yhat.dtype, 'sanity check'

#     # class distribution of stage='train'
#     w = T.tensor([249, 781, 450], dtype=y.dtype, device=y.device)
#     w = (w.max() / w).reshape(1, 3)
#     # w can have any of the shapes:  (B,1) or (1,C) or (B,C)
#     #  return T.nn.functional.binary_cross_entropy_with_logits(yhat, y, weight=w)
#     return T.nn.functional.cross_entropy(yhat, y, weight=w)
#     # can't apply focal loss unless do it manually.


# def onehot(y, nclasses):
#     return T.zeros((y.numel(), nclasses), dtype=y.dtype, device=y.device)\
#             .scatter_(1, y.unsqueeze(1), 1)


# def _upsample_pad_minibatch_imgs_to_same_size(batch, target_is_segmentation_mask=False):
#     """a collate function for a dataloader of (x,y) samples.  """
#     shapes = [item[0].shape for item in batch]
#     H = max(h for c,h,w in shapes)
#     W = max(w for c,h,w in shapes)
#     X, Y = [], []
#     for item in batch:
#         h,w = item[0].shape[1:]
#         dh, dw = (H-h), (W-w)
#         padding = (dw//2, dw-dw//2, dh//2, dh-dh//2, )
#         X.append(T.nn.functional.pad(item[0], padding))
#         if target_is_segmentation_mask:
#             Y.append(T.nn.functional.pad(item[1], padding))
#         else:
#             Y.append(item[1])
#     return T.stack(X), T.stack(Y)


# def get_dset_chexpert(train_frac=.8, val_frac=.2, small=False,
#                       labels:str='diagnostic', num_identities=None):
#     """
#     Args:
#         labels:  either "diagnostic" (the 14 classes defined as
#             D.CheXpert.LABELS_DIAGNOSTIC) or "identity" ("patient", "study",
#             "view", "index")
#         small:  whether to use CheXpert_Small dataset (previously downsampled
#             images) or the fully size dataset.
#         num_identities:  used only if labels='identity'.  If
#             num_identities=1000, then all patients get identified as coming
#             from precisely 1 of 1000 bins.

#     Returns:
#         (
#         {'train_dset': ..., 'val_dset': ..., 'test_dset': ...,
#          'train_loader': ..., 'val_loader': ..., 'test_loader': ...
#          },

#         ('Pneumonia', 'Cardiomegaly', ...)  # class names defined by `labels`
#         )
#     """
#     _label_cleanup_dct = dict(D.CheXpert.LABEL_CLEANUP_DICT)
#     if labels == 'diagnostic':
#         class_names = D.CheXpert.LABELS_DIAGNOSTIC
#         for k in class_names:
#             _label_cleanup_dct[k][np.nan] = 0  # remap missing value to negative
#         get_ylabels = lambda dct: \
#                 D.CheXpert.format_labels(dct, labels=class_names).float()
#     elif labels == 'identity':
#         class_names = list(range(num_identities))
#         get_ylabels = lambda dct: \
#                 (D.CheXpert.format_labels(dct, labels=['index']) % num_identities).long()
#     else:
#         raise NotImplementedError(f"unrecognized labels: {labels}")
#     kws = dict(
#         img_transform=tvt.Compose([
#             #  tvt.RandomCrop((512, 512)),
#             tvt.ToTensor(),  # full res 1024x1024 imgs
#         ]),
#         getitem_transform=lambda dct: (dct['image'], get_ylabels(dct)),
#         label_cleanup_dct=_label_cleanup_dct,
#     )
#     if small:
#         kls = D.CheXpert_Small
#     else:
#         kls = D.CheXpert

#     train_dset = kls(dataset_dir="../data/CheXpert-v1.0-small/",use_train_set=True, **kws)  #Edited Elvin

#     N = len(train_dset)
#     if train_frac + val_frac == 1:
#         nsplits = [N - int(N*val_frac), int(N*val_frac), 0]
#     else:
#         a,b = int(N*train_frac), int(N*val_frac)
#         nsplits = [a,b, N-a-b]
#     train_dset, val_dset, _ = T.utils.data.random_split(train_dset, nsplits)
#     test_dset = kls(dataset_dir="../data/CheXpert-v1.0-small/",use_train_set=False, **kws) #Edited Elvin
#     batch_dct = dict(
#         batch_size=15, collate_fn=_upsample_pad_minibatch_imgs_to_same_size,
#         num_workers=int(os.environ.get("num_workers", 4)))  # upsample pad must take time
#     train_loader=DataLoader(train_dset, shuffle=True, **batch_dct)
#     val_loader=DataLoader(val_dset, **batch_dct)
#     test_loader=DataLoader(test_dset, **batch_dct)
#     return (dict(
#         train_dset=train_dset, val_dset=val_dset, test_dset=test_dset,
#         train_loader=train_loader, val_loader=val_loader, test_loader=test_loader,
#     ), class_names)


# def get_dset_intel_mobileodt(stage_trainval:str, use_val:str, stage_test:str, augment:str
#                              ) -> (dict[str,Optional[Union[Dataset,DataLoader]]], tuple[str]):
#     """Obtain train/val/test splits for the IntelMobileODT Cervical Cancer
#     Colposcopy dataset, and the data loaders.

#     Args:
#         stage_trainval: the `stage` for training and validation.
#             i.e. Possible choices:  {'train', 'train+additional'}
#             Train / val split is 70/30 random stratified split.
#         use_val: Whether to create a validation set
#             Choices:  {"val", "noval"}
#         stage_test: the `stage` for test set.  Should be "test".
#         augment: Type of augmentations to apply.  One of {'v1', }.
#             "v1" - make the aspect ratio .75, resize images to (200,150), and convert in range [0,1]
#     Returns:
#         (
#         {'train_dset': ..., 'val_dset': ..., 'test_dset': ...,
#          'train_loader': ..., 'val_loader': ..., 'test_loader': ...
#          },

#         ('Type 1', 'Type 2', 'Type 3')
#         )
#     """
#     assert augment == 'v1', 'code bug: other augmentations not implemented'
#     base_dir = './data/intel_mobileodt_cervical_resized'
#     dset_trainval = D.IntelMobileODTCervical(stage_trainval, base_dir)
#     _y = [dset_trainval.getitem(i, load_img=False)
#           for i in range(len(dset_trainval))]
#     dct = {'test_dset': D.IntelMobileODTCervical(stage_test, base_dir)}
#     if use_val == 'noval':
#         dct['train_dset'] = dset_trainval
#         dct['val_dset'] = None
#     else:
#         assert use_val == 'val', f'unrecognized option: {use_val}'
#         idxs_train, idxs_val = list(
#             StratifiedShuffleSplit(1, test_size=.3).split(
#                 np.arange(len(dset_trainval)), _y))[0]
#         dct['train_dset'] = T.utils.data.Subset(dset_trainval, idxs_train)
#         dct['val_dset'] = T.utils.data.Subset(dset_trainval, idxs_val)

#     # preprocess train/val/test images all the same way
#     preprocess_v1 = tvt.Compose([
#         #
#         ### previously done (to save computation time) ###
#         #  D.IntelMobileODTCervical.fix_aspect_ratio,
#         #  tvt.Resize((200, 150)),  # interpolation=tvt.InterpolationMode.NEAREST),
#         #
#         lambda x: x.float()/255.
#     ])
#     dct = {k: D.PreProcess(v, lambda xy: (
#         preprocess_v1(xy[0]),
#         #  onehot(xy[1].unsqueeze(0).long()-1, 3).squeeze_().float()))
#         xy[1].long()-1))
#         for k,v in dct.items()}
#     dct.update(dict(
#         train_loader=DataLoader(dct['train_dset'], batch_size=20, shuffle=True),
#         test_loader=DataLoader(dct['test_dset'], batch_size=20),))
#     if dct['val_dset'] is None:
#         dct['val_loader'] = None
#     else:
#         dct['val_loader'] = DataLoader(dct['val_dset'], batch_size=20)
#     class_names = [x.replace('_', ' ') for x in D.IntelMobileODTCervical.LABEL_NAMES]
#     return dct, class_names


# LOSS_FNS = {
#     ('BCEWithLogitsLoss', ): lambda _: T.nn.BCEWithLogitsLoss(),
#     ('CrossEntropyLoss', ): lambda _: T.nn.CrossEntropyLoss(),
#     ('CE_intelmobileodt', ): lambda _: loss_intelmobileodt,
#     ('chexpert_uignore', ): lambda _: LossCheXpertUignore(),
#     ('chexpert_identity', str): lambda out_ch: LossCheXpertIdentity(N=int(out_ch)),
# }

# DSETS = {
#     ('intel_mobileodt', str, str, str, str): (
#         lambda train, val, test, aug: get_dset_intel_mobileodt(train, val, test, aug)),
#     #  ('origa', ... todo): ( lambda ...: get_dset_origa(...)
#     #  ('riga', ... todo): ( lambda ...: get_dset_riga(...)
#     ('chexpert', str, str): (
#         lambda train_frac, val_frac: get_dset_chexpert(
#             float(train_frac), float(val_frac), small=False, labels='diagnostic')),
#     ('chexpert_small', str, str): (
#         lambda train_frac, val_frac: get_dset_chexpert(
#             float(train_frac), float(val_frac), small=True, labels='diagnostic')),
#     ('chexpert_small_ID', str, str, str): (
#         lambda num_identities, train_frac, val_frac: get_dset_chexpert(
#             float(train_frac), float(val_frac), small=True,
#             labels='identity', num_identities=int(num_identities))),
# }


# def match(spec:str, dct:dict):
#     return pampy.match(spec.split(':'), *(x for y in dct.items() for x in y))


# def get_model_opt_loss(
#         model_spec:str, opt_spec:str, loss_spec:str, regularizer_spec:str,
#         device:str) -> dict[str, Union[T.nn.Module, T.optim.Optimizer]]:
#     """
#     Args:
#         model_spec: a string of form,
#             "model_name:pretraining:in_channels:out_classes".  For example:
#             "effnetv2:untrained:1:5"
#         opt_spec: Specifies how to create optimizer.
#             First value is a pytorch Optimizer in T.optim.*.
#             Other values are numerical parameters.
#             Example: "SGD:lr=.003:momentum=.9"
#         device: e.g. 'cpu' or 'gpu'
#     Returns:
#         a pytorch model and optimizer
#     """
#     mdl = match(model_spec, MODELS)
#     mdl = mdl.to(device, non_blocking=True)
#     optimizer = reset_optimizer(opt_spec, mdl)
#     loss_fn = match(loss_spec, LOSS_FNS)
#     if regularizer_spec != 'none':
#         loss_fn = RegularizedLoss(mdl, loss_fn, regularizer_spec)
#     return dict(model=mdl, optimizer=optimizer, loss_fn=loss_fn)


# class RegularizedLoss(T.nn.Module):
#     def __init__(self, model, lossfn, regularizer_spec:str):
#         super().__init__()
#         self.lossfn = lossfn
#         self.regularizer_spec = regularizer_spec
#         if regularizer_spec == 'none':
#             self.regularizer = lambda *y: 0
#         elif regularizer_spec.startswith('deepfixmlp:'):
#             lbda = float(regularizer_spec.split(':')[1])
#             self.regularizer = lambda *y: (
#                 float(lbda) * DeepFixMLP.get_VecAttn_regularizer(model))
#         else:
#             raise NotImplementedError(regularizer_spec)

#     def forward(self, yhat, y):
#         return self.lossfn(yhat, y) + self.regularizer(yhat, y)

#     def __repr__(self):
#         return f'RegularizedLoss<{repr(self.lossfn)},{self.regularizer_spec}>'


# def get_dset_loaders_resultfactory(dset_spec:str) -> dict:
#     dct, class_names = match(dset_spec, DSETS)
#     if any(dset_spec.startswith(x) for x in {'intel_mobileodt:',
#                                              'chexpert_small_ID:'}):
#         #  dct['result_factory'] = lambda: TL.MultiLabelBinaryClassification(
#                 #  class_names, binarize_fn=lambda yh: (T.sigmoid(yh)>.5).long())
#         dct['result_factory'] = lambda: TL.MultiClassClassification(
#                 len(class_names), binarize_fn=lambda yh: yh.softmax(1).argmax(1))
#     elif any(dset_spec.startswith(x) for x in {'chexpert:', 'chexpert_small:'}):
#         dct['result_factory'] = lambda: CheXpertMultiLabelBinaryClassification(
#             class_names, binarize_fn=lambda yh: (yh.sigmoid()>.5).long(), report_avg=True)
#     else:
#         raise NotImplementedError(f"I don't know how to create the result factory for {dset_spec}")
#     return dct

# class CheXpertMultiLabelBinaryClassification(TL.MultiLabelBinaryClassification):
#     def update(self, yhat, y, loss) -> None:
#         self.num_samples += yhat.shape[0]
#         self.loss += loss.item()
#         assert yhat.shape == y.shape
#         assert yhat.ndim == 2 and yhat.shape[1] == len(self._cms), "sanity check: model outputs expected prediction shape"
#         binarized = self._binarize_fn(yhat)
#         assert binarized.dtype == T.long, 'sanity check binarize fn'
#         assert binarized.shape == y.shape, 'sanity check binarize fn'
#         ignore = (y != 2)  # ignore uncertainty labels
#         for i, (kls, cm) in enumerate(self._cms.items()):
#             rows = ignore[:, i]
#             if rows.sum() == 0:
#                 continue  # don't update a confusion matrix if all data for this class is ignored
#             cm += metrics.confusion_matrix(y[rows, i], binarized[rows, i], num_classes=2).cpu()


# def get_deepfix_train_strategy(args:'TrainOptions'):
#     deepfix_spec = args.deepfix
#     if deepfix_spec == 'off':
#         return TL.train_one_epoch
#     elif deepfix_spec.startswith('reinit:'):
#         _, N, P, R = deepfix_spec.split(':')
#         return dfs.DeepFix_TrainOneEpoch(int(N), float(P), int(R), TL.train_one_epoch)
#     elif deepfix_spec.startswith('dhist:'):
#         fp = deepfix_spec.split(':', 1)[1]
#         assert exists(fp), f'histogram file not found: {fp}'
#         return dfs.DeepFix_DHist(fp)
#     elif deepfix_spec.startswith('dfhist:'):
#         fp = deepfix_spec.split(':', 1)[1]
#         assert exists(fp), f'histogram file not found: {fp}'
#         return dfs.DeepFix_DHist(fp, fixed=True)
#     elif deepfix_spec == 'fixed':
#         return dfs.DeepFix_DHist('', fixed=True, init_with_hist=False)
#     elif deepfix_spec.startswith('beta:'):
#         alpha, beta = deepfix_spec.split(':')[1:]
#         return dfs.DeepFix_LambdaInit(
#             lambda cfg: init_from_beta(cfg.model, float(alpha), float(beta)))
#     elif deepfix_spec.startswith('ghaarconv2d:'):
#         ignore_layers = deepfix_spec.split(':')[1].split(',')
#         return dfs.DeepFix_LambdaInit(
#             lambda cfg: (
#                 print(f'initialize {deepfix_spec}'),
#                 convert_conv2d_to_gHaarConv2d(cfg.model, ignore_layers=ignore_layers),
#                 reset_optimizer(args.opt, cfg.model),
#                 print(cfg.model)
#             ))
#     else:
#         raise NotImplementedError(deepfix_spec)


# def train_config(args:'TrainOptions') -> TL.TrainConfig:
#     return TL.TrainConfig(
#         **get_model_opt_loss(
#             args.model, args.opt, args.lossfn, args.loss_reg, args.device),
#         **get_dset_loaders_resultfactory(args.dset),
#         device=args.device,
#         epochs=args.epochs,
#         start_epoch=args.start_epoch,
#         train_one_epoch=get_deepfix_train_strategy(args),
#         experiment_id=args.experiment_id,
#     )


# @dc.dataclass
# class TrainOptions:
#     """High-level configuration for training PyTorch models
#     on the IntelMobileODTCervical dataset.
#     """
#     epochs:int = 50
#     start_epoch:int = 0  # if "--start_epoch 1", then don't evaluate perf before training.
#     device:str = 'cuda' if T.cuda.is_available() else 'cpu'
#     dset:str = None #choice(
#         #  'intel_mobileodt:train:val:test:v1',
#         #  'intel_mobileodt:train+additional:val:test:v1',
#         #  'intel_mobileodt:train+additional:noval:test:v1',
#         #  'chexpert:.8:.2', 'chexpert:.01:.01', 'chexpert:.001:.001',
#         #  'chexpert_small:.8:.2', 'chexpert_small:.01:.01',
#         #   'chexpert_small:.001:.001',
#         #  default='intel_mobileodt:train:val:test:v1')
#     opt:str = 'SGD:lr=.001:momentum=.9:nesterov=1'
#     lossfn:str = None  # choices:
#         #  'BCEWithLogitsLoss',
#         #  'CrossEntropyLoss', 
#         #  'CE_intelmobileodt',
#         #  'chexpert_uignore', 
#         #  'chexpert_identity:N' for some N=num_identities predicted by model (compared to identities y%N)
#     loss_reg:str = 'none'  # Optionally add a regularizer to the loss.  loss + reg.  Accepted values:  'none', 'deepfixmlp:X' where X is a positive float denoting the lambda in l1 regularizer
#     model:str = 'resnet18:imagenet:3:3'  # Model specification adheres to the template "model_name:pretraining:in_ch:out_ch"
#     deepfix:str = 'off'  # DeepFix Re-initialization Method.
#                          #  "off" or "reinit:N:P:R" or "d[f]hist:path_to_histogram.pth"
#                          #  or "beta:A:B" for A,B as (float) parameters of the beta distribution
#                          # 'ghaarconv2d:layer1,layer2' Replaces all spatial convolutions with GHaarConv2d layer except the specified layers
#     experiment_id:str = os.environ.get('run_id', 'debugging')
#     prune:str = 'off'

#     def execute(self):
#         cfg = train_config(self)
#         cfg.train(cfg)


# def main():
#     p = ArgumentParser()
#     p.add_arguments(TrainOptions, dest='TrainOptions')

# #     args = p.parse_args(["--dset", "chexpert_small:.01:.01", "--opt", "Adam:lr=0.001", "--lossfn", "chexpert_uignore", "--model", "waveletmlp:300:1:14:7:1:1:2", "--loss_reg", "none"]).TrainOptions

#     print(args)
#     cfg = train_config(args)
    
# # python deepfix/train.py --dset chexpert_small:.01:.01 --opt Adam:lr=0.001 --lossfn chexpert_uignore --model waveletmlp:300:1:14:7:1:1:2 --loss_reg none    
    
#     if args.prune != 'off':
#         assert args.prune.startswith('ChannelPrune:')
#         raise NotImplementedError('code is a bit hardcoded, so it is not available without hacking on it.')
#         print(args.prune)
#         from explainfix import channelprune
#         from deepfix.weight_saliency import costfn_multiclass
#         a = sum([x.numel() for x in cfg.model.parameters()])
#         channelprune(cfg.model, pct=5, grad_cost_fn=costfn_multiclass,
#                      loader=cfg.train_loader, device=cfg.device, num_minibatches=10)
#         b = sum([x.numel() for x in cfg.model.parameters()])
#         assert a/b != 1
#         print(f'done channelpruning.  {a/b}')

#     cfg.train(cfg)
#     #  import IPython ; IPython.embed() ; import sys ; sys.exit()

#     #  with T.profiler.profile(
#     #      activities=[
#     #          T.profiler.ProfilerActivity.CPU,
#     #          T.profiler.ProfilerActivity.CUDA,
#     #      ], with_modules=True,
#     #  ) as p:
#     #      cfg.train(cfg)
#     #  print(p.key_averages().table(
#     #      sort_by="self_cuda_time_total", row_limit=-1))


# if __name__ == "__main__":
#     main()

# %%
# os.getcwd()
# !ls

# %%
# args = {}
# args['dset'] = 'chexpert_small:.01:.01'
# args['opt'] = 'Adam:lr=0.001'
# args['lossfn'] = 'chexpert_uignore'
# args['model'] = 'waveletmlp:300:1:14:7:1:1:2'
# args['loss_reg'] = None
# args['prune'] = 'off'

# %%
# args.dset

# %%
# import pandas as pd

# %%
# t = pd.read_csv('../data/CheXpert-v1.0-small/train.csv')
