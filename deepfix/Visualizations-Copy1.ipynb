# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
# %run -m simplepytorch.plot_perf "resnet18|norm|Layer|level_3_patch_size_32_loss_reg_none" -c "BAcc AVG" --mode 3
clear_output(wait=True)
plt.figure(1)   
plt.legend(loc="lower right")

# %%
# %run -m simplepytorch.plot_perf "resnet18|norm|Layer|level_3_patch_size_32_loss_reg_none" -c "Acc AVG" --mode 3
clear_output(wait=True)
plt.figure(1)   
plt.legend(loc="lower right")
