# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
# %run -m simplepytorch.plot_perf "resnet18|model_waveletmlpV2:1:14:coif1:3:32:l1_level_3_patch_size_32chexpert_small15k:.9:.1:diagnostic_batchnorm1d_|model_waveletmlpV2:1:14:coif1:3:32:l1_level_3_patch_size_32chexpert_small15k:.9:.1:diagnostic_LayerNorm_|model_waveletmlpV2:1:14:coif1:3:32:l1_level_3_patch_size_32_loss_reg_none_dataset_chexpert_small15k:.9:.1:diagnostic" -c "BAcc AVG" --mode 3
clear_output(wait=True)
plt.figure(1)   
plt.legend(loc="lower right")

# %%
# %run -m simplepytorch.plot_perf "resnet18|model_waveletmlpV2:1:14:coif1:3:32:l1_level_3_patch_size_32chexpert_small15k:.9:.1:diagnostic_batchnorm1d_|model_waveletmlpV2:1:14:coif1:3:32:l1_level_3_patch_size_32chexpert_small15k:.9:.1:diagnostic_LayerNorm_|model_waveletmlpV2:1:14:coif1:3:32:l1_level_3_patch_size_32_loss_reg_none_dataset_chexpert_small15k:.9:.1:diagnostic" -c "Acc AVG" --mode 3
clear_output(wait=True)
plt.figure(1)   
plt.legend(loc="lower right")

# %%
# %run -m simplepytorch.plot_perf "resnet18|batchnorm" -c "Acc AVG" --mode 3
clear_output(wait=True)
plt.figure(1)   
plt.legend(loc="lower right")

# %%
# %run -m simplepytorch.plot_perf "resnet18|LayerNorm" -c "Acc AVG" --mode 3
clear_output(wait=True)
plt.figure(1)   
plt.legend(loc="lower right")
