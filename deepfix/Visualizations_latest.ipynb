# %%
from IPython.display import clear_output

# %%
# %run -m simplepytorch.plot_perf model_efficientnet-b0:imagenet:1:14_in_ch_1out_ch_14 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_efficientnet-b0:imagenet:1:14_in_ch_1out_ch_14 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4  
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_efficientnet-b1:imagenet:1:14_in_ch_1out_ch_14 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_efficientnet-b1:imagenet:1:14_in_ch_1out_ch_14 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_effnetv2:untrained:1:14_in_ch_1out_ch_14 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_effnetv2:untrained:1:14_in_ch_1out_ch_14 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_resnet18:imagenet:1:14_in_ch_1_out_ch_14 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_resnet18:imagenet:1:14_in_ch_1_out_ch_14 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_resnet50:imagenet:1:14_in_ch_1out_ch_14 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_resnet50:imagenet:1:14_in_ch_1out_ch_14 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4  
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletres18:imagenet:1:14_in_ch_1out_ch_14 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletres18:imagenet:1:14_in_ch_1out_ch_14 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4 
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:1:32:1:2_level_1_patch_size_32 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:1:32:1:2_level_1_patch_size_32 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4  
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:2:32:1:2_level_2_patch_size_32 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:2:32:1:2_level_2_patch_size_32 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:3:32:1:2_level_3_patch_size_32 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:3:32:1:2_level_3_patch_size_32 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4 
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:1:64:1:2_level_1_patch_size_64 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:1:64:1:2_level_1_patch_size_64 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:2:64:1:2_level_2_patch_size_64 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:2:64:1:2_level_2_patch_size_64 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4 
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:1:128:1:2_level_1_patch_size_128 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:1:128:1:2_level_1_patch_size_128 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:1:1:1:2_level_1_patch_size_1 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:1:1:1:2_level_1_patch_size_1 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4 
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:2:1:1:2_level_2_patch_size_1 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:2:1:1:2_level_2_patch_size_1 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4 
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:3:32:1:2_level_3_patch_size_3 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:3:32:1:2_level_3_patch_size_3 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4  
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:4:1:1:2_level_4_patch_size_1 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:4:1:1:2_level_4_patch_size_1 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:5:1:1:2_level_5_patch_size_1 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:5:1:1:2_level_5_patch_size_1 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:6:1:1:2_level_6_patch_size_1 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:6:1:1:2_level_6_patch_size_1 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4  
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:7:1:1:2_level_7_patch_size_1 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:7:1:1:2_level_7_patch_size_1 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4 
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:8:1:1:2_level_8_patch_size_1 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:8:1:1:2_level_8_patch_size_1 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4 
clear_output(wait=False)

# %%
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:9:1:1:2_level_9_patch_size_1 -c "Loss" --no-shell --mode 4
# %run -m simplepytorch.plot_perf model_waveletmlp:300:1:14:9:1:1:2_level_9_patch_size_1 -c 'Loss|(MCC|BAcc|Acc) AVG' --no-shell --mode 4 
clear_output(wait=False)
